# %% [markdown]
# * Word2Vec models require a lot of text, e.g. the entire Wikipedia corpus.
# * Learning a word embedding from text involves **loading and organizing the text into sentences** and providing them to the constructor of a new Word2Vec() instance.
# * Specifically, **each sentence must be tokenized, meaning divided into words and prepared** (e.g. perhaps pre-filtered and perhaps converted to a preferred case).
# * The sentences could be text loaded into memory, or an iterator that progressively loads text, required for very large text corpora.
#
# There are many parameters on this constructor; a few noteworthy arguments you may wish to configure are:
#
# * size: (default 100) The number of dimensions of the embedding, e.g. the length of the dense vector to represent each token (word).
# * window: (default 5) The maximum distance between a target word and words around the target word.
# * min_count: (default 5) The minimum count of words to consider when training the model; words with an occurrence less than this count will be ignored.
# * workers: (default 3) The number of threads to use while training.
# * sg: (default 0 or CBOW) The training algorithm, either CBOW (0) or skip gram (1).
#
# After the model is trained, it is accessible via the “wv” attribute. This is the actual word vector model in which queries can be made.
# * Finally, a trained model can then be saved to file by calling the **save_word2vec_format()** function on the word vector model.
# * The saved model can then be loaded again by calling the **Word2Vec.load()** function.

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
import numpy as np

# %%
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
# fit a 2d PCA model to the vectors
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# /Users/Andrew/anaconda/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# * In lexical analysis, **tokenization is the process of breaking a stream of text up into words, phrases, symbols, or other meaningful elements called tokens**.
#
# We want to tokenize each string to get a list of words, usually by making everything lowercase and splitting along the spaces. In contrast, lemmatization involves getting the root of each word, which can be helpful but is more computationally expensive (enough so that you would want to preprocess your text rather than do it on-the-fly).

# %%
model.wv.syn0.
# Out:
# /Users/Andrew/anaconda/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.
# (14, 100)

# %%
a = np.load('we.npz')

# %%
a['arr_0'].reshape(100, 2001)
# Out:
# array([[ 0.7423402 ,  0.6229428 , -0.11326306, ...,  0.03066378,
#          0.84130025,  0.13939072],
#        [ 0.06406816, -0.36339754,  0.2329111 , ..., -0.10166003,
#          0.3842291 , -0.15549025],
#        [ 0.0285372 , -0.09085478, -0.4237251 , ...,  0.18987326,
#         -0.05013648,  0.41674453],
#        ...,
#        [-0.11503438, -0.03075912,  0.1304221 , ...,  0.16334139,
#         -0.01173837, -0.16708732],
#        [ 0.20468706,  0.04894143, -0.01450396, ...,  0.05354125,
#          0.05104723,  0.02716174],
#        [-0.11779221, -0.05250452, -0.05520123, ...,  0.9906901 ,
#         -0.9552681 ,  0.5116191 ]], dtype=float32)

# %%
a['arr_1']
# Out:
# array([[-0.38631386,  0.20147815,  0.6479255 , ..., -0.13058957,
#         -0.01945282,  0.72976243],
#        [ 0.63986766, -0.14248417, -0.04158743, ...,  0.06458516,
#         -0.13147248,  0.793282  ],
#        [ 0.27124068,  0.17855947,  0.40957147, ...,  0.06983739,
#          0.04165047, -0.03286304],
#        ...,
#        [ 0.3228462 ,  0.34071591,  0.11076628, ...,  0.0508968 ,
#          0.01842172,  0.17464632],
#        [-0.2784434 , -0.24281913,  0.28136414, ...,  0.11481141,
#          0.01115797, -0.0513269 ],
#        [ 0.6009526 , -0.22841343,  0.2567979 , ..., -0.06322522,
#         -0.00614684, -0.2129331 ]], dtype=float32)

# %%
from nltk.corpus import reuters

# %%
for fields in reuters.fileids():
    sentence = reuters.words(fields)
    print(sentence)
# Out:
# ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', ...]
# ['CHINA', 'DAILY', 'SAYS', 'VERMIN', 'EAT', '7', '-', ...]
# ['JAPAN', 'TO', 'REVISE', 'LONG', '-', 'TERM', ...]
# ['THAI', 'TRADE', 'DEFICIT', 'WIDENS', 'IN', 'FIRST', ...]
# ['INDONESIA', 'SEES', 'CPO', 'PRICE', 'RISING', ...]
# ['AUSTRALIAN', 'FOREIGN', 'SHIP', 'BAN', 'ENDS', 'BUT', ...]
# ['INDONESIAN', 'COMMODITY', 'EXCHANGE', 'MAY', ...]
# ['SRI', 'LANKA', 'GETS', 'USDA', 'APPROVAL', 'FOR', ...]
# ['WESTERN', 'MINING', 'TO', 'OPEN', 'NEW', 'GOLD', ...]
# ['SUMITOMO', 'BANK', 'AIMS', 'AT', 'QUICK', 'RECOVERY', ...]
# ['SUBROTO', 'SAYS', 'INDONESIA', 'SUPPORTS', 'TIN', ...]
# ['BUNDESBANK', 'ALLOCATES', '6', '.', '1', 'BILLION', ...]
# ['BOND', 'CORP', 'STILL', 'CONSIDERING', 'ATLAS', ...]
# ['CHINA', 'INDUSTRIAL', 'OUTPUT', 'RISES', 'IN', ...]
# ['JAPAN', 'MINISTRY', 'SAYS', 'OPEN', 'FARM', 'TRADE', ...]
# ['AMATIL', 'PROPOSES', 'TWO', '-', 'FOR', '-', 'FIVE', ...]
# ['BOWATER', '1986', 'PRETAX', 'PROFITS', 'RISE', '15', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'DEFICIT', ...]
# ['SOUTH', 'KOREA', 'MOVES', 'TO', 'SLOW', 'GROWTH', ...]
# ['FINNS', 'AND', 'CANADIANS', 'TO', 'STUDY', 'MTBE', ...]
# ['CRA', 'SOLD', 'FORREST', 'GOLD', 'FOR', '76', 'MLN', ...]
# ['GERMAN', 'INDUSTRIAL', 'EMPLOYMENT', 'SEEN', ...]
# ['BOWATER', 'INDUSTRIES', 'PROFIT', 'EXCEED', ...]
# ['CITIBANK', 'NORWAY', 'UNIT', 'LOSES', 'SIX', 'MLN', ...]
# ['VIEILLE', 'MONTAGNE', 'SAYS', '1986', 'CONDITIONS', ...]
# ['VIEILLE', 'MONTAGNE', 'REPORTS', 'LOSS', ',', ...]
# ['EC', 'MAINLY', 'FOR', 'TIN', 'EXTENSION', ',', 'NO', ...]
# ['JAPAN', 'GIVEN', 'LITTLE', 'HOPE', 'OF', 'AVOIDING', ...]
# ['THAI', 'ZINC', 'EXPORTS', 'FALL', 'IN', 'MARCH', ...]
# ['EC', 'SUGAR', 'TENDER', 'HARD', 'TO', 'PREDICT', '-', ...]
# ['NORTH', 'YEMEN', 'CALLS', 'SUGAR', 'BUYING', ...]
# ['ANHEUSER', '-', 'BUSCH', 'JOINS', 'BID', 'FOR', ...]
# ['ECONOMIC', 'SPOTLIGHT', '-', 'AUSTRALIAN', 'MARKETS', ...]
# ['ECONOMIC', 'SPOTLIGHT', '-', 'KUWAITI', 'ECONOMY', ...]
# ['MALAYSIA', 'MAY', 'NOT', 'MEET', '1987', 'OIL', ...]
# ['JARDINE', 'MATHESON', 'SAID', 'IT', 'SETS', 'TWO', ...]
# ['MONIER', 'SAYS', 'BRITAIN', "'", 'S', 'REDLAND', ...]
# ['ISUZU', 'PLANS', 'NO', 'INTERIM', 'DIVIDEND', ...]
# ['JAPANESE', 'OFFICIAL', 'TAKES', 'DATA', 'TO', ...]
# ['BELL', 'GROUP', 'CONFIRMS', 'STANDARD', 'CHARTERED', ...]
# ['NIPPON', 'STEEL', 'DENIES', 'CHINA', 'SEEKING', ...]
# ['JARDINE', 'MATHESON', 'REPLACES', '"', 'B', '"', ...]
# ['JAPAN', 'GIVEN', 'LITTLE', 'HOPE', 'OF', 'AVOIDING', ...]
# ['BANK', 'OF', 'JAPAN', 'INTERVENES', 'SOON', 'AFTER', ...]
# ['INDONESIAN', 'INFLATION', 'RATE', '8', '.', '8', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'GIVEN', '53', ...]
# ['SAN', 'MIGUEL', 'DEAL', 'HIT', 'BY', 'MORE', ...]
# ['RAIN', 'BOOSTS', 'CENTRAL', 'QUEENSLAND', 'SUGAR', ...]
# ['FRENCH', 'TRADERS', 'FORECAST', 'EC', 'SUGAR', ...]
# ['ITALY', "'", 'S', 'LA', 'FONDIARIA', 'TO', 'REPORT', ...]
# ['NICKEL', 'PRICES', 'UNLIKELY', 'TO', 'RISE', 'MUCH', ...]
# ['HIGHER', '1986', 'PROFIT', 'FOR', 'DUTCH', ...]
# ['POEHL', 'WARNS', 'AGAINST', 'FURTHER', 'DOLLAR', ...]
# ['CINCINNATI', 'BELL', '&', 'lt', ';', 'CSN', '>', ...]
# ['CALIFORNIA', 'BIOTECH', '&', 'lt', ';', 'CBIO', '>', ...]
# ['PALL', 'CORP', '&', 'lt', ';', 'PLL', '>', 'SETS', ...]
# ['UNILEVER', 'SEEKS', 'BUYER', 'FOR', 'STAUFFER', ...]
# ['CONRAC', 'CORP', 'SAID', 'IT', 'HAS', 'ENTERED', ...]
# ['CONRAC', '&', 'lt', ';', 'CAX', '>', 'IN', 'MERGER', ...]
# ['JAPAN', "'", 'S', 'LDP', 'URGES', 'MORE', 'IMPORTS', ...]
# ['COMPUTER', 'RESEARCH', 'INC', '&', 'lt', ';', 'CORE', ...]
# ['AUSTRALIAN', 'FOREIGN', 'SHIP', 'BAN', 'ENDS', 'Tug', ...]
# ['RUBBERMAID', 'INC', '1ST', 'QTR', 'SHR', '28', 'CTS', ...]
# ['INDEPENDENT', 'CHAIRMAN', 'FOR', 'DUTCH', 'CARGO', ...]
# ['ELECTRO', 'RENT', 'CORP', '&', 'lt', ';', 'ELRC', ...]
# ['RUBBERMAID', 'INC', '&', 'lt', ';', 'RBD', '>', ...]
# ['WTC', 'INTERNATIONAL', 'INC', '&', 'lt', ';', 'WAF', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'GIVEN', ...]
# ['MEAD', 'CORP', '1ST', 'QTR', 'OPER', 'SHR', '1', '.', ...]
# ['RUBBERMAID', '&', 'lt', ';', 'RBD', '>', 'SEES', ...]
# ['CAYUGA', 'SAVINGS', 'BANK', '&', 'lt', ';', 'CAYB', ...]
# ['JOHNSTOWN', 'SAVINGS', 'BANK', 'FSB', '&', 'lt', ';', ...]
# ['HOME', 'SAVINGS', 'AND', 'LOAN', 'ASSOCIATION', ...]
# ['GEODYNAMICS', 'CORP', '&', 'lt', ';', 'GDYN', '>', ...]
# ['SWEDISH', 'UNEMPLOYMENT', 'STEADY', 'IN', 'MARCH', ...]
# ['COMPAQ', '&', 'lt', ';', 'CPQ', '>', 'EXPECTS', ...]
# ['I', '.', 'U', '.', 'INTERNATIONAL', '&', 'lt', ';', ...]
# ['CXR', 'TELCOM', 'CORP', '&', 'lt', ';', 'CXRL', '>', ...]
# ['PROXMIRE', 'OUTLINES', 'INSIDER', 'TRADING', ...]
# ['HELEN', 'OF', 'TROY', 'CORP', '&', 'lt', ';', 'HELE', ...]
# ['BANKERS', 'TRUST', '&', 'lt', ';', 'BT', '>', 'PUTS', ...]
# ['&', 'lt', ';', 'FIRST', 'MERCANTILE', 'CURRENCY', ...]
# ['UK', 'INTERVENTION', 'BD', 'SAYS', 'EC', 'SOLD', ...]
# ['STOLTENBERG', 'SEES', 'MOVES', 'TO', 'STRENGTHEN', ...]
# ['U', '.', 'K', '.', 'INTERVENTION', 'BOARD', ...]
# ['MEAD', '&', 'lt', ';', 'MEA', '>', 'EXPECTS', ...]
# ['AMERTEK', 'INC', '&', 'lt', ';', 'ATEKF', '>', '1ST', ...]
# ['ALEX', 'BROWN', 'INC', '&', 'lt', ';', 'ABSB', '>', ...]
# ['TOWN', 'AND', 'COUNTRY', 'JEWELRY', 'MANUFACTURING', ...]
# ['PAXAR', 'CORP', '&', 'lt', ';', 'PAKS', '>', 'MAKES', ...]
# ['&', 'lt', ';', 'MARK', "'", 'S', 'WORK', 'WEARHOUSE', ...]
# ['CANADIAN', 'BASHAW', ',', 'ERSKINE', 'RESOURCES', ...]
# ['ENTOURAGE', '&', 'lt', ';', 'ENTG', '>', 'HAS', ...]
# ['&', 'lt', ';', 'MR', '.', 'JAX', 'FASHIONS', 'INC', ...]
# ['F', '.', 'W', '.', 'WOOLWORTH', 'CO', 'SAYS', 'IT', ...]
# ['F', '.', 'W', '.', 'WOOLWORTH', 'CO', '&', 'lt', ';', ...]
# ['DUTCH', 'SUGAR', 'BEET', 'PLANTING', 'HALF', ...]
# ['J', '.', 'P', '.', 'MORGAN', 'AND', 'CO', 'INC', ...]
# ['EC', 'COMMISSION', 'DETAILS', 'SUGAR', 'TENDER', ...]
# ['VOLKSWAGEN', 'DIVIDEND', 'DECISION', 'DUE', ...]
# ['CITYTRUST', 'BANCORP', 'INC', '&', 'lt', ';', 'CITR', ...]
# ['SOUTHMARK', '&', 'lt', ';', 'SM', '>', 'ACQUIRES', ...]
# ['J', '.', 'P', '.', 'MORGAN', 'AND', 'CO', 'INC', '&', ...]
# ['FIRSTBANC', 'CORP', 'OF', 'OHIO', '&', 'lt', ';', ...]
# ['MAYFAIR', 'SUPER', 'MARKETS', 'INC', '&', 'lt', ';', ...]
# ['HANOVER', 'INSURANCE', '&', 'lt', ';', 'HINS', '>', ...]
# ['NATIONAL', 'GUARDIAN', '&', 'lt', ';', 'NATG', '>', ...]
# ['UNIVERSAL', 'MEDICAL', '&', 'lt', ';', 'UMBIZ', '>', ...]
# ['ZAMBIA', 'DOES', 'NOT', 'PLAN', 'RETAIL', 'MAIZE', ...]
# ['WEDGESTONE', 'REALTY', '&', 'lt', ';', 'WDG', '>', ...]
# ['SUN', '&', 'lt', ';', 'SUN', '>', 'CUTS', 'HEATING', ...]
# ['FURTHER', 'ARGENTINE', 'COARSE', 'GRAIN', 'LOSSES', ...]
# ['DUTCH', 'ADJUSTED', 'UNEMPLOYMENT', 'RISES', 'IN', ...]
# ['8', '-', 'APR', '-', '1987', '11', ':', '06', ':', ...]
# ['TOP', 'OFFICIALS', 'ARRIVE', 'AT', 'TREASURY', 'FOR', ...]
# ['FED', 'EXPECTED', 'TO', 'SET', 'CUSTOMER', ...]
# ['READER', "'", 'S', 'DIGEST', 'ASSOCIATION', 'SELLS', ...]
# ['WEIS', 'MARKETS', 'INC', '&', 'lt', ';', 'WMK', '>', ...]
# ['CONTINENTAL', 'BANK', 'INITIAL', 'DISTRIBUTION', ...]
# ['ATLAS', 'CONSOLIDATED', 'MINING', 'AND', ...]
# ['SCI', '-', 'MED', '&', 'lt', ';', 'SMLS', '>', ...]
# ['FIDELCOR', '&', 'lt', ';', 'FICR', '>', 'COMPLETES', ...]
# ['DATA', 'TRANSLATION', 'INC', '&', 'lt', ';', 'DATX', ...]
# ['ENERGY', '/', 'U', '.', 'S', '.', 'PETROCHEMICAL', ...]
# ['FIDATA', 'CORP', '&', 'lt', ';', 'FID', '>', '4TH', ...]
# ['MARBLE', 'FINANCIAL', 'CORP', '&', 'lt', ';', 'MRBL', ...]
# ['DOMINION', 'TEXTILE', 'CALLS', 'REPORT', 'OF', 'BID', ...]
# ['RAYTHEON', 'CO', '1ST', 'QTR', 'SHR', '1', '.', '37', ...]
# ['FLEET', 'FINANCIAL', 'GROUP', '1ST', 'QTR', 'SHR', ...]
# ['DIEBOLD', 'INC', '&', 'lt', ';', 'DBD', '>', ...]
# ['INDEPENDENT', 'BANK', 'CORP', '&', 'lt', ';', 'IBCP', ...]
# ['RAYTHEON', 'CO', '&', 'lt', ';', 'RTN', '>', '1ST', ...]
# ['WALTHAM', 'SAVINGS', 'BANK', '&', 'lt', ';', 'WLBK', ...]
# ['FLEET', 'FINANCIAL', 'GROUP', '&', 'lt', ';', 'FLT', ...]
# ['DOMINION', 'CALLS', 'BURLINGTON', '&', 'lt', ';', ...]
# ['FED', 'SETS', 'OVERNIGHT', 'SYSTEM', 'REPURCHASES', ...]
# ['RAYTHEON', '&', 'lt', ';', 'RTN', '>', 'NET', ...]
# ['GENERAL', 'INSTRUMENT', 'CORP', '&', 'lt', ';', ...]
# ['COCOA', 'EXPORTERS', 'EXPECTED', 'TO', 'LIMIT', ...]
# ['FED', 'ADDS', 'RESERVES', 'VIA', 'OVERNIGHT', ...]
# ['HONDURAS', 'SEEKING', 'PL', '-', '480', 'BULK', ...]
# ['J', '.', 'P', '.', 'MORGAN', '&', 'lt', ';', 'JPM', ...]
# ['ATLAS', 'CONSOLIDATED', 'MINING', '&', 'lt', ';', ...]
# ['BRAZIL', 'GRAIN', 'HARVEST', 'FACES', 'STORAGE', ...]
# ['FLEET', '&', 'lt', ';', 'FLT', '>', 'SHAREHOLDERS', ...]
# ['ROWE', 'FURNITURE', 'CORP', '&', 'lt', ';', 'ROWE', ...]
# ['REUTERS', 'CHAIRMAN', 'URGES', 'FREER', ...]
# ['CCL', 'INDUSTRIES', 'PURCHASES', 'STAKE', 'IN', ...]
# ['PARIS', 'GROUP', 'PUBLISHING', 'DAILY', 'FRANC', ...]
# ['RHODES', 'INC', '&', 'lt', ';', 'RHD', '>', ...]
# ['MADEIRA', 'IN', 'LETTER', 'OF', 'INTENT', 'TO', 'BE', ...]
# ['CELLTRONICS', '&', 'lt', ';', 'CELT', '>', ...]
# ['MONTEDISON', "'", 'S', 'AGRIMONT', 'UNIT', '1986', ...]
# ['DATRON', '&', 'lt', ';', 'DATR', '>', 'AGREES', 'TO', ...]
# ['TRUMP', 'AND', 'INTERSTATE', 'PROPERTIES', 'IN', ...]
# ['SOUND', 'WAREHOUSE', 'INC', '&', 'lt', ';', 'SWHI', ...]
# ['TRUMP', 'AND', 'INTERSTATE', 'IN', 'TALKS', 'FOR', ...]
# ['JAPAN', 'BUYS', '4', ',', '000', 'TONNES', ...]
# ['TELECRAFTER', 'CORP', '&', 'lt', ';', 'SWHI', '>', ...]
# ['TUNISIA', 'EXPECTED', 'TO', 'TENDER', 'FOR', ...]
# ['COLT', 'INDUSTRIES', 'INC', '&', 'lt', ';', 'COT', ...]
# ['YANKEE', '&', 'lt', ';', 'YNK', '>', 'UNIT', 'NOT', ...]
# ['MAYFAIR', 'SUPER', 'MARKETS', 'INC', '&', 'lt', ';', ...]
# ['&', 'lt', ';', 'BATON', 'BROADCASTING', 'INC', '>', ...]
# ['UNITED', 'CABLE', 'TELEVISION', 'CORP', '&', 'lt', ...]
# ['CANADA', 'ALLOWS', 'PUBLISHING', 'TAKEOVER', 'BY', ...]
# ['TALKING', 'POINT', '/', 'BURLINGTON', 'INDUSTRIES', ...]
# ['STERIVET', 'LABORATORIES', 'LTD', '&', 'lt', ';', ...]
# ['STERIVET', 'LABORATORIES', 'LTD', '&', 'lt', ';', ...]
# ['JAPAN', 'IN', 'LAST', '-', 'DITCH', 'EFFORT', 'TO', ...]
# ['HOECHST', 'CELANESE', 'SENDS', 'REPORT', 'ON', 'NEW', ...]
# ['MELLON', 'PARTICIPATING', 'MORTGAGE', 'TRUST', '&', ...]
# ['U', '.', 'K', '.', 'GEC', 'DECLINES', 'COMMENT', ...]
# ['PRESTON', 'CORP', '&', 'lt', ';', 'PTRK', '>', ...]
# ['WHITE', 'HOUSE', 'STANDING', 'FIRM', 'ON', ...]
# ['DOW', 'JONES', 'AND', 'CO', 'INC', 'FIRST', ...]
# ['&', 'lt', ';', 'HAYES', '-', 'DANA', 'INC', '>', ...]
# ['COCOA', 'TERMINAL', 'DEPOSITS', 'TO', 'BE', 'CUT', ...]
# ['ELECTRO', 'RENT', 'CORP', '&', 'lt', ';', 'ELRC', ...]
# ['WALGREEN', 'CO', '2ND', 'QTR', 'SHR', '62', 'CTS', ...]
# ['JUDY', "'", 'S', 'INC', '&', 'lt', ';', 'JUDY', '>', ...]
# ['ORANGE', '-', 'CO', 'INC', '&', 'lt', ';', 'OJ', '>', ...]
# ['DOW', 'JONES', 'AND', 'CO', 'INC', '&', 'lt', ';', ...]
# ['LORD', 'ABBETT', 'AND', 'CO', 'MUTUAL', 'FUND', ...]
# ['HEINEKEN', 'SEES', 'HIGHER', 'PROFITS', ',', 'WIDER', ...]
# ['WALGREEN', 'CO', '&', 'lt', ';', 'WAG', '>', 'VOTES', ...]
# ['COLOMBIA', 'BUSINESS', 'ASKED', 'TO', 'DIVERSIFY', ...]
# ['TURKEY', 'CALLS', 'FOR', 'DIALOGUE', 'TO', 'SOLVE', ...]
# ['FRONTIER', 'INSURANCE', '&', 'lt', ';', 'FRTR', '>', ...]
# ['FRONTIER', 'INSURANCE', 'GROUP', 'INC', '&', 'lt', ...]
# ['GATT', 'OFFICIAL', 'MEETS', 'WITH', 'U', '.', 'S', ...]
# ['SOUTHINGTON', 'SAVINGS', 'BANK', '&', 'lt', ';', ...]
# ['CATERPILLAR', 'INC', '&', 'lt', ';', 'CAT', '>', ...]
# ['CORRECTED', '-', 'DATRON', '&', 'lt', ';', 'DATR', ...]
# ['WALGREEN', 'CO', '&', 'lt', ';', 'WAG', '>', '2ND', ...]
# ['J', '.', 'P', '.', 'MORGAN', '&', 'lt', ';', 'JPM', ...]
# ['MEDTRONIC', '&', 'lt', ';', 'MDT', '>', 'SEES', '15', ...]
# ['SPIE', 'BATIGNOLLES', 'COULD', 'INCREASE', ...]
# ['TALKS', 'CONTINUE', 'ON', 'TIN', 'AGREEMENT', ...]
# ['PAKISTAN', 'COTTON', 'CROP', 'SEEN', 'RECORD', '7', ...]
# ['TRANZONIC', 'COS', '&', 'lt', ';', 'TNZ', '>', '4TH', ...]
# ['SECURITY', 'PACIFIC', 'EXPECTS', 'BRAZIL', 'LOAN', ...]
# ['WHITE', 'HOUSE', 'SAYS', 'JAPANESE', 'TARRIFFS', ...]
# ['SHOWBOAT', '&', 'lt', ';', 'SBO', '>', 'TO', 'TAKE', ...]
# ['SECURITY', 'PACIFIC', '&', 'lt', ';', 'SPC', '>', ...]
# ['IRAQI', 'TROOPS', 'REPORTED', 'PUSHING', 'BACK', ...]
# ['GOLDEN', 'ENTERPRISES', 'INC', '&', 'lt', ';', ...]
# ['GROUP', 'OF', 'FIVE', 'MEETING', 'ENDS', 'A', ...]
# ['USDA', 'TO', 'PROPOSE', 'FOREIGN', 'MEAT', ...]
# ['UNION', 'TEXAS', 'OIL', 'RESERVES', 'DROPPED', 'IN', ...]
# ['UAL', '&', 'lt', ';', 'UAL', '>', 'MAY', 'RESPOND', ...]
# ['HARTMARX', '&', 'lt', ';', 'HMX', '>', 'TARGETS', ...]
# ['FED', "'", 'S', 'HELLER', 'SEES', 'RETURN', 'TO', ...]
# ['GENERAL', 'ELECTRIC', 'CO', '1ST', 'QTR', 'SHR', '1', ...]
# ['GHANA', 'TO', 'BUY', 'CRUDE', 'OIL', 'FROM', 'IRAN', ...]
# ['FED', "'", 'S', 'HELLER', 'SAYS', 'MONETARY', ...]
# ['GENERAL', 'ELECTRIC', 'CO', '&', 'lt', ';', 'GE', ...]
# ['ENERGY', 'DEVELOPMENT', '&', 'lt', ';', 'EDP', '>', ...]
# ['INDUSTRIAL', 'NATIONS', 'RECONVENE', 'FOR', 'TALKS', ...]
# ['U', '.', 'S', '.', 'MEAT', ',', 'POULTRY', ...]
# ['CHRYSLER', '&', 'lt', ';', 'C', '>', 'RENAULT', ...]
# ['RITE', 'AID', 'CORP', '&', 'lt', ';', 'RAD', '>', ...]
# ['AIRSENSORS', 'INC', '&', 'lt', ';', 'ARSN', '>', ...]
# ['CANADA', 'PLANS', 'TO', 'MONITOR', 'STEEL', ...]
# ['GENERAL', 'ELECTRIC', '&', 'lt', ';', 'GE', '>', ...]
# ['TECK', 'STILL', 'IN', 'TALKS', 'ON', 'B', '.', 'C', ...]
# ['BANPONCE', 'CORP', '&', 'lt', ';', 'BDEP', '>', ...]
# ['XEBEC', '&', 'lt', ';', 'XEBC', '>', 'TO', 'REPORT', ...]
# ['CCC', 'ACCEPTS', 'EXPORT', 'BID', 'FOR', 'WHEAT', ...]
# ['EGYPT', 'AUTHORIZED', 'TO', 'BUY', 'PL', '-', '480', ...]
# ['CATERPILLAR', '&', 'lt', ';', 'CAT', '>', ...]
# ['BROKER', 'BOOSTS', 'ZONDERVAN', '&', 'lt', ';', ...]
# ['KIENA', 'TWO', '-', 'FOR', '-', 'ONE', 'SHARE', ...]
# ['HANOVER', 'INSURANCE', '&', 'lt', ';', 'HINS', '>', ...]
# ['DAY', 'INT', "'", 'L', '&', 'lt', ';', 'DAY', '>', ...]
# ['RITE', 'AID', 'CORP', '&', 'lt', ';', 'RAD', '>', ...]
# ['SOUTH', 'KOREA', 'CORN', 'IMPORTS', 'MAY', ...]
# ['MEXICAN', 'CATTLE', 'IMPORTS', 'TO', 'BE', 'BRANDED', ...]
# ['VULCAN', '&', 'lt', ';', 'VUL', '>', 'SEES', 'FIRST', ...]
# ['UAL', '&', 'lt', ';', 'UAL', '>', 'HAS', 'NO', ...]
# ['STRATA', 'CORP', '&', 'lt', ';', 'STATA', '>', ...]
# ['STRATA', '&', 'lt', ';', 'STATA', '>', '1986', ...]
# ['DAYTON', 'HUDSON', 'CORP', '&', 'lt', ';', 'DH', '>', ...]
# ['VULCAN', 'CORP', '&', 'lt', ';', 'VUL', '>', ...]
# ['NAT', "'", 'L', 'DISTILLERS', 'SAYS', 'IT', 'AGREES', ...]
# ['USDA', 'SEEKS', 'COMMENTS', 'ON', 'GRAIN', ...]
# ['CASCADE', 'IMPORTERS', 'UNIT', 'ACQUIRES', 'PARIS', ...]
# ['ARMEL', 'INC', '&', 'lt', ';', 'AML', '>', '4TH', ...]
# ['NATIONAL', 'DISTILLERS', '&', 'lt', ';', 'DR', '>', ...]
# ['MANAGEMENT', 'SCIENCE', '&', 'lt', ';', 'MSAI', '>', ...]
# ['WOJNILOWER', 'SEES', 'DROP', 'IN', 'U', '.', 'S', ...]
# ['RAYTECH', '&', 'lt', ';', 'RAY', '>', 'BUYS', 'WEST', ...]
# ['INTERCARE', '&', 'lt', ';', 'CARE', '>', 'TO', ...]
# ['CANADA', 'TO', 'MONITOR', 'STEEL', 'IMPORTS', ',', ...]
# ['UNITED', 'TECH', '&', 'lt', ';', 'UTX', '>', 'SEES', ...]
# ['STEWART', 'AND', 'STEVENSON', '&', 'lt', ';', 'SSSS', ...]
# ['WESTAMERICA', 'BANCORP', '&', 'lt', ';', 'WAB', '>', ...]
# ['U', '.', 'S', '.', 'SENATE', 'LIFTS', 'SOME', 'BANS', ...]
# ['SOUTHEAST', 'BANCORP', '&', 'lt', ';', 'STB', '>', ...]
# ['WILLIAMS', '&', 'lt', ';', 'WMB', '>', 'SEES', ...]
# ['SUPER', 'VALU', 'STORES', 'INC', '&', 'lt', ';', ...]
# ['PARKER', 'DRILLING', 'CO', '&', 'lt', ';', 'PKD', ...]
# ['COFFEE', 'COULD', 'DROP', 'TO', '70', '/', '80', ...]
# ['HBO', '&', 'lt', ';', 'HBOC', '>', 'URGES', ...]
# ['(', 'CFCF', 'INC', ')', 'SIX', 'MTHS', 'FEB', '28', ...]
# ['UAP', 'MAKES', 'ACQUISITIONS', '&', 'lt', ';', 'UAP', ...]
# ['EIA', 'SAYS', 'DISTILLATE', 'STOCKS', 'UNCHANGED', ...]
# ['USDA', 'DISCUSSING', 'PL', '480', 'AGREEMENT', ...]
# ['EIA', 'SAYS', 'DISTILLATE', 'STOCKS', 'UNCHANGED', ...]
# ['HAWKEYE', '&', 'lt', ';', 'HWKB', '>', '1986', ...]
# ['&', 'lt', ';', 'WASHINGTON', 'BANCORPORATION', '>', ...]
# ['DOME', '&', 'lt', ';', 'DMP', '>', 'PLAN', 'MAY', ...]
# ['RECENT', 'U', '.', 'S', '.', 'OIL', 'DEMAND', 'OFF', ...]
# ['DEFICIT', 'CUTS', 'SEEN', 'UNABLE', 'TO', 'CURE', ...]
# ['STEWART', 'AND', 'STEVENSON', 'SERVICES', '&', 'lt', ...]
# ['WESTAMERICA', 'BANCORPORATION', '&', 'lt', ';', ...]
# ['COLOMBIA', 'COFFEE', 'REGISTRATIONS', 'REMAIN', ...]
# ['GATEWAY', 'BANCORP', 'INC', '&', 'lt', ';', 'GBAN', ...]
# ['MORE', 'AMERICAN', 'BRANDS', '&', 'lt', ';', 'AMB', ...]
# ['BUNDESBANK', 'CALLS', 'FOR', 'CENTRAL', 'BANK', ...]
# ['AUSTRALIAN', 'UNEMPLOYMENT', 'RISES', 'IN', 'MARCH', ...]
# ['CSR', 'SAYS', 'IT', 'IS', 'RETAINING', 'NON', '-', ...]
# ['JAPAN', 'MINISTRY', 'HAS', 'NO', 'COMMENT', 'ON', ...]
# ['SHOWA', 'DENKO', 'EXPORTS', 'ALUMINIUM', 'CASTING', ...]
# ['ECONOMIC', 'SPOTLIGHT', '-', 'TELECOM', 'IS', 'KEY', ...]
# ['G', '-', '7', 'ISSUES', 'STATEMENT', 'AFTER', ...]
# ['BANK', 'OF', 'FRANCE', 'TO', 'HOLD', 'MONEY', ...]
# ['RIO', 'TINTO', '-', 'ZINC', 'CORP', 'PLC', '1986', ...]
# ['RIO', 'TINTO', '-', 'ZINC', 'NET', 'ATTRIBUTABLE', ...]
# ['Burmah', 'Oil', '1986', 'pre', '-', 'tax', 'profit', ...]
# ['GERMAN', 'BANKERS', "'", 'REMARKS', 'REVIVE', 'TALK', ...]
# ['SOVIET', 'TRADE', 'DEFICIT', 'WITH', 'WEST', 'SOARS', ...]
# ['BURMAH', 'OIL', 'PROFIT', 'CLIMBS', 'TO', '105', '.', ...]
# ['CHINA', "'", 'S', 'WHEAT', 'CROP', 'THREATENED', ...]
# ['RTZ', 'SEES', 'RISING', 'U', '.', 'S', '.', 'OUTPUT', ...]
# ['BRIDGESTONE', 'CORP', '&', 'lt', ';', 'BRIT', '.', ...]
# ['EC', 'SUGAR', 'TENDER', 'SEEN', 'MARKING', 'NO', ...]
# ['BURMAH', 'OIL', 'PROSPECTS', 'REMAIN', 'FAVOURABLE', ...]
# ['GEBRUEDER', 'SULZER', '1986', 'PROFIT', 'UP', ...]
# ['JAPAN', 'BUSINESS', 'LEADERS', 'SAY', 'G', '-', '7', ...]
# ['PERGAMON', 'HOLDINGS', 'REDUCES', 'BPCC', 'AND', ...]
# ['NATIONALE', 'NEDERLANDEN', 'PROFITS', ',', 'SALES', ...]
# ['SHANGHAI', 'TYREb', 'FACTORY', 'TO', 'RAISE', '30', ...]
# ['SAUDI', 'RATES', 'RISE', 'AS', 'BAHRAIN', 'BANKS', ...]
# ['BELGIUM', 'TO', 'ISSUE', 'GOLD', 'WARRANTS', ',', ...]
# ['PHILIPPINE', 'TELEPHONE', 'FIRM', 'PLANS', 'STOCK', ...]
# ['CARGILL', 'CONFIRMS', 'WHITE', 'SUGAR', 'SALE', 'TO', ...]
# ['MALAYSIA', 'SEEKS', '42', 'BILLION', 'YEN', ...]
# ['CCF', 'REPORTS', '34', '.', '8', 'PCT', 'PROFIT', ...]
# ['JOHNSON', 'MATTHEY', "'", 'S', 'PLATINUM', 'GROUP', ...]
# ['LEX', 'SERVICE', 'BUYS', 'SEARS', 'MOTOR', 'GROUP', ...]
# ['MAJOR', 'RUBBER', 'PRODUCERS', 'TO', 'MEET', 'IN', ...]
# ['MEPC', 'EXTENDS', 'OFFER', 'FOR', 'OLDHAM', 'MEPC', ...]
# ['GEORGE', 'WIMPEY', 'PROFITS', 'UP', '42', 'PCT', ...]
# ['CANADA', 'FEBRUARY', 'TRADE', 'SURPLUS', '1', '.', ...]
# ['AEGON', '1986', 'NET', 'PROFIT', 'RISES', '6', '.', ...]
# ['CANADA', 'FEBRUARY', 'TRADE', 'SURPLUS', '1', '.', ...]
# ['BANK', 'OF', 'JAPAN', 'BUYS', 'DOLLARS', 'IN', ...]
# ['MIYAZAWA', 'SAYS', 'YEN', 'STILL', 'INSIDE', 'PARIS', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'GETS', '103', ...]
# ['NATNED', 'FORECASTS', '1987', 'RESULTS', 'IN', ...]
# ['9', '-', 'APR', '-', '1987', '07', ':', '38', ':', ...]
# ['EUROPEAN', 'MARKETS', 'REACT', 'QUIETLY', 'TO', 'G', ...]
# ['GERMAN', 'MONEY', 'MARKET', 'SPLIT', 'ON', 'LOWER', ...]
# ['THAILAND', 'TO', 'RENEW', 'LONG', 'TERM', 'SUGAR', ...]
# ['EC', 'LAUNCHES', 'ANTI', '-', 'DUMPING', 'PROBE', ...]
# ['SWISS', 'TO', 'LAUNCH', 'NEW', 'SERIES', 'OF', ...]
# ['EUROPEAN', 'MARKETS', 'REACT', 'QUIETLY', 'TO', 'G', ...]
# ['FINANCE', 'MINISTERS', 'AGREE', 'ON', 'NEED', 'FOR', ...]
# ['AEGON', 'EXPECTS', 'MODERATE', 'RISE', 'IN', '1987', ...]
# ['G', '-', '7', 'ISSUES', 'STATEMENT', 'AFTER', ...]
# ['G', '-', '7', 'WANTS', 'TO', 'SHOW', 'MARKETS', ...]
# ['YEN', 'SEEN', 'RISING', 'AFTER', 'G', '-', '7', ...]
# ['JAPAN', 'BUSINESS', 'LEADERS', 'SAY', 'G', '-', '7', ...]
# ['UNIFIRST', 'CORP', '&', 'lt', ';', 'UNF', '>', ...]
# ['&', 'lt', ';', 'TRUMP', 'PLAZA', '>', '4TH', 'QTR', ...]
# ['EUROPEAN', 'MARKETS', 'REACT', 'QUIETLY', 'TO', 'G', ...]
# ['WEST', 'GERMAN', 'BEET', 'PLANTINGS', 'DELAYED', ...]
# ['STEP', '-', 'SAVER', '&', 'lt', ';', 'CODA', '>', ...]
# ['COAST', 'SAVINGS', '&', 'lt', ';', 'CSA', '>', 'IN', ...]
# ['BRAMALL', 'TO', 'ACQUIRE', 'GELCO', 'FOR', 'UP', ...]
# ['BELGIUM', 'LAUNCHES', 'BONDS', 'WITH', 'GOLD', ...]
# ['FAO', 'SEES', 'LOWER', 'GLOBAL', 'WHEAT', ',', ...]
# ['CB', 'AND', 'T', 'BANCSHARES', 'INC', '&', 'lt', ';', ...]
# ['XICOR', 'INC', '&', 'lt', ';', 'XICO', '>', '1ST', ...]
# ['GEORGE', 'WIMPEY', 'SAYS', 'BENEFITS', 'OF', ...]
# ['C', '.', 'O', '.', 'M', '.', 'B', '.', '&', 'lt', ...]
# ['BELGIUM', 'LAUNCHES', 'BONDS', 'WITH', 'GOLD', ...]
# ['DATATRAK', 'INC', '&', 'lt', ';', 'DTRK', '>', '3RD', ...]
# ['MIYAZAWA', 'SAYS', 'YEN', 'STILL', 'INSIDE', 'PARIS', ...]
# ['TODD', 'SHIPYARDS', '&', 'lt', ';', 'TOD', '>', ...]
# ['U', '.', 'S', '.', 'FIRST', 'TIME', 'JOBLESS', ...]
# ['CLEVITE', 'INDUSTRIES', 'SAYS', 'J', '.', 'P', '.', ...]
# ['SUNTRUST', 'BANKS', 'INC', '&', 'lt', ';', 'STI', ...]
# ['INTERNATIONAL', 'THOMSON', 'TO', 'REPORT', 'IN', 'U', ...]
# ['PHILIP', 'CROSBY', 'ASSOCIATES', 'INC', '&', 'lt', ...]
# ['COLONIAL', 'AMERICAN', 'BANKSHARES', 'CORP', '&', ...]
# ['RPT', '-', 'ARGENTINE', 'GRAIN', '/', 'OILSEED', ...]
# ['CLEVITE', '&', 'lt', ';', 'CLEV', '>', 'GETS', '13', ...]
# ['JAPAN', 'BUSINESS', 'LEADERS', 'SAY', 'G', '-', '7', ...]
# ['ARGENTINE', 'CATTLE', 'MARKET', 'REPORT', 'ABOUT', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'DEFICIT', ...]
# ['PHYSIO', 'TECHNOLOGY', '&', 'lt', ';', 'PHYT', '>', ...]
# ['WASHINGTON', 'FEDERAL', 'SAVINGS', '&', 'lt', ';', ...]
# ['U', '.', 'S', '.', 'ENERGY', 'FUTURES', 'CALLED', ...]
# ['PONCE', 'FEDERAL', 'BANK', 'F', '.', 'S', '.', 'B', ...]
# ['BUNDESBANK', 'SEES', 'NO', 'REASON', 'TO', 'CHANGE', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'DEFICIT', ...]
# ['LEBANESE', 'POUND', 'FALLS', 'SHARPLY', 'AGAINST', ...]
# ['BROWN', 'BOVERI', 'UND', 'CIE', 'AG', 'LIFTS', ...]
# ['LONDON', 'FREIGHT', 'MARKET', 'FEATURES', 'GRAIN', ...]
# ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...]
# ['WHIRLPOOL', 'CORP', '1ST', 'QTR', 'SHR', '66', 'CTS', ...]
# ['BRAZILIAN', 'SOY', 'RAINFALL', 'THE', 'FOLLOWING', ...]
# ['BUNDESBANK', 'SEES', 'NO', 'CHANGE', 'IN', ...]
# ['BRAZILIAN', 'COFFEE', 'RAINFALL', 'THE', 'FOLLOWING', ...]
# ['E', '.', 'F', '.', 'HUTTON', 'LBO', 'INC', 'SAID', ...]
# ['WORLD', 'BANK', 'TO', 'SUPPORT', 'SRI', 'LANKA', ...]
# ['E', '.', 'F', '.', 'HUTTON', 'LBO', 'INC', 'SAYS', ...]
# ['GEMINA', 'HAS', 'NO', 'COMMENT', 'ON', 'AMBROSIANO', ...]
# ['VOLKSWAGEN', 'DIVIDEND', 'UNCHANGED', 'ON', '1986', ...]
# ['WHIRLPOOL', 'CORP', '&', 'lt', ';', 'WHR', '>', ...]
# ['U', '.', 'S', '.', 'SAID', 'TO', 'VIEW', 'G', '-', ...]
# ['BANK', 'OF', 'FRANCE', 'LEAVES', 'INTERVENTION', ...]
# ['GLOBAL', 'ECONOMIC', 'SLOWDOWN', 'RAISES', 'NEW', ...]
# ['SPANISH', 'EMPLOYERS', 'WORRIED', 'BY', 'HIGH', ...]
# ['SHOWBOAT', '&', 'lt', ';', 'SBO', '>', 'DECLARES', ...]
# ['LEAD', 'PRICES', 'RISE', 'ON', 'FINELY', 'BALANCED', ...]
# ['REXHAM', 'CORP', '&', 'lt', ';', 'RXH', '>', '1ST', ...]
# ['FIRST', 'EASTERN', 'CORP', '&', 'lt', ';', 'FEBC', ...]
# ['FHLBB', 'CHANGES', 'SHORT', '-', 'TERM', 'DISCOUNT', ...]
# ['ANCHOR', 'FINANCIAL', '&', 'lt', ';', 'AFCX', '>', ...]
# ['STOLTENBERG', 'NOT', 'SURPRISED', 'BY', 'DOLLAR', ...]
# ['ASARCO', 'UPS', 'U', '.', 'S', '.', 'LEAD', 'PRICE', ...]
# ['E', '.', 'F', '.', 'HUTTON', '&', 'lt', ';', 'EFH', ...]
# ['ABBOTT', 'LABORATORIES', '1ST', 'QTR', 'NET', 'SHR', ...]
# ['INDIA', 'FOODGRAIN', 'TARGET', '160', 'MLN', ...]
# ['CERTIFICATED', 'COTTON', 'STOCKS', 'Certificated', ...]
# ['REICHHOLD', 'CHEMICAL', '&', 'lt', ';', 'RCI', '>', ...]
# ['ABBOTT', 'LABORATORIES', 'INC', '&', 'lt', ';', ...]
# ['HANSON', '&', 'lt', ';', 'HAN', '>', 'TO', 'BUY', ...]
# ['EGYPT', 'BUYS', 'PL', '480', 'WHEAT', 'FLOUR', '-', ...]
# ['SPAIN', 'HAS', '35', 'MLN', 'DLR', 'CURRENT', ...]
# ['INDIA', 'OILSEED', 'OUTPUT', 'FORECAST', 'TO', ...]
# ['EXXON', '&', 'lt', ';', 'XON', '>', 'SOUTH', ...]
# ['SALLIE', 'MAE', 'ADJUSTS', 'SHORT', '-', 'TERM', ...]
# ['FREDDIE', 'MAC', 'ADJUSTS', 'SHORT', '-', 'TERM', ...]
# ['ARGENTINE', 'GRAIN', 'BELT', 'WEATHER', 'REPORT', ...]
# ['VW', 'SAYS', '480', 'MLN', 'MARKS', 'MAXIMUM', 'FOR', ...]
# ['YUGOSLAVIA', 'TO', 'TENDER', 'FOR', '100', ',', ...]
# ['FEDERATED', 'DEPARTMENT', 'STORES', 'MARCH', 'SALES', ...]
# ['PRICES', 'GENERALLY', 'LOWER', 'AT', 'NAIROBI', ...]
# ['ALEX', '.', 'BROWN', '&', 'lt', ';', 'ABSB', '>', ...]
# ['HIGHLAND', 'SUPERSTORES', 'INC', '&', 'lt', ';', ...]
# ['LVI', 'GROUP', '&', 'lt', ';', 'LVI', '>', 'TO', ...]
# ['TEXAS', 'AMERICAN', '&', 'lt', ';', 'TAE', '>', ...]
# ['VORNADO', 'INC', '&', 'lt', ';', 'VNO', '>', '4TH', ...]
# ['BRENDA', 'MINES', 'SELLING', 'KERR', 'ADDISON', ...]
# ['PHOENIX', 'FINANCIAL', '&', 'lt', ';', 'PHFC', '>', ...]
# ['HEALTH', 'AND', 'REHABILITATION', '&', 'lt', ';', ...]
# ['T', '.', 'ROWE', 'PRICE', '&', 'lt', ';', 'TROW', ...]
# ['GENERAL', 'PARTNERS', 'CUTS', 'STAKE', 'IN', ...]
# ['HERITAGE', 'FINANCIAL', 'SERVICES', '&', 'lt', ';', ...]
# ['NATIONAL', 'COMPUTER', '&', 'lt', ';', 'NLCS', '>', ...]
# ['U', '.', 'K', '.', 'CHANCELLOR', 'LAWSON', 'SAYS', ...]
# ['REXHAM', '&', 'lt', ';', 'RXH', '>', 'REPURCHASES', ...]
# ['EXXON', '&', 'lt', ';', 'XON', '>', 'CUTS', ...]
# ['FHLBB', 'CHANGES', 'SHORT', '-', 'TERM', 'DISCOUNT', ...]
# ['&', 'lt', ';', 'STRATHFIELD', 'OIL', 'AND', 'GAS', ...]
# ['FED', 'MAY', 'ADD', 'RESERVES', 'TO', 'BANKING', ...]
# ['DIAMOND', 'CRYSTAL', '&', 'lt', ';', 'DSLT', '>', ...]
# ['LAWSON', 'SAYS', 'SOME', 'COUNTRIES', 'COULD', 'CUT', ...]
# ['FRENCH', 'FREE', 'MARKET', 'CEREAL', 'EXPORT', ...]
# ['U', '.', 'K', '.', 'POTATO', 'FUTURES', 'TRADING', ...]
# ['GROUP', 'OF', '10', 'WELCOMES', 'LATEST', 'G', '-', ...]
# ['CANAM', 'MANAC', 'WINS', '8', '.', '5', 'MLN', 'DLR', ...]
# ['SPOT', 'TIN', 'EASIER', 'ON', 'EUROPEAN', 'FREE', ...]
# ['DOLLAR', 'ENDS', 'LOWER', 'IN', 'LACKLUSTRE', ...]
# ['CONSOLIDATED', 'PAPERS', 'INC', '&', 'lt', ';', ...]
# ['HUMANA', '&', 'lt', ';', 'HUM', '>', 'TO', 'SELL', ...]
# ['MET', '-', 'COIL', 'SYSTEMS', 'CORP', '&', 'lt', ';', ...]
# ['FORD', 'RAISES', 'QTLY', 'PAYOUT', '10', 'CTS', '/', ...]
# ['LAWSON', 'SEES', 'NO', 'CHANGE', 'IN', 'U', '.', 'K', ...]
# ['FORD', 'MOTOR', 'CO', '&', 'lt', ';', 'F', '>', ...]
# ['TALKING', 'POINT', '/', 'STEEL', 'COMPANIES', ...]
# ['DEKALB', 'CORP', '&', 'lt', ';', 'DKLBB', '>', '2ND', ...]
# ['ABBOTT', '&', 'lt', ';', 'ABT', '>', 'SEES', 'GAINS', ...]
# ['EASTERN', 'DISTRIBUTIVE', 'BEEF', 'TRADE', 'WEEKLY', ...]
# ['BRAZIL', 'COTTON', 'CROP', 'LOWER', '--', 'USDA', ...]
# ['TREASURY', "'", 'S', 'BAKER', 'SAYS', 'TRADE', ',', ...]
# ['EC', 'AUTHORISES', 'EXPORT', '55', ',', '000', ...]
# ['EC', 'AUTHORISES', 'EXPORT', '65', ',', '000', ...]
# ['RJR', 'NABISCO', 'FIRST', 'QUARTER', 'NET', 'TO', ...]
# ['BRAZIL', 'COCOA', 'EXPORTERS', 'UNLIKELY', 'TO', ...]
# ['HEALTH', '/', 'REHABILITATION', '&', 'lt', ';', ...]
# ['U', '.', 'S', '.', 'TREASURY', "'", 'S', 'BAKER', ...]
# ['TIME', '&', 'lt', ';', 'TL', '>', 'TO', 'SELL', ...]
# ['SPRINKEL', 'SAYS', 'TAX', 'HIKE', 'WOULD', 'NOT', ...]
# ['ROYAL', 'BUSINESS', 'GROUP', 'INC', '&', 'lt', ';', ...]
# ['&', 'lt', ';', 'MSE', 'CABLE', 'SYSTEMS', 'INC', '>', ...]
# ['RULE', 'INDUSTRIES', 'INC', '&', 'lt', ';', 'RULE', ...]
# ['NEW', 'JERSEY', 'INVESTOR', 'BUYS', '5', '.', '2', ...]
# ['NATIONAL', 'DISTILLERS', '&', 'lt', ';', 'DR', '>', ...]
# ['WEATHER', 'HURTS', 'ITALIAN', 'ORANGES', '-', 'USDA', ...]
# ['EC', 'GRANTS', 'FREE', 'MARKET', 'BARLEY', ',', ...]
# ['FED', 'BUYING', 'DOLLARS', 'FOR', 'YEN', 'IN', ...]
# ['WASTE', 'RECOVERY', 'INC', '&', 'lt', ';', 'WRII', ...]
# ['BRANCH', 'CORP', '&', 'lt', ';', 'BNCH', '>', '1ST', ...]
# ['KURZ', '-', 'KASCH', 'UPS', 'STAKE', 'IN', ...]
# ['BRAZIL', 'SOYBEAN', 'YIELDS', 'SEEN', 'AVERAGE', '-', ...]
# ['ZAYRE', 'CORP', '&', 'lt', ';', 'ZY', '>', 'RAISES', ...]
# ['FED', 'SEEN', 'BUYING', 'DOLLARS', 'FOR', 'YEN', ...]
# ['RJR', 'NABISCO', '&', 'lt', ';', 'RJR', '>', 'HAS', ...]
# ['BAYBANKS', 'INC', '&', 'lt', ';', 'BBNK', '>', '1ST', ...]
# ['FRANCE', "'", 'S', 'BALLADUR', 'SAYS', 'TARGET', ...]
# ['STUDENT', 'LOAN', 'MARKETING', 'ASSOCIATION', '&', ...]
# ['FIRE', 'AT', 'TATE', '/', 'LYLE', 'LONDON', 'JETTY', ...]
# ['JP', 'INDUSTRIES', '&', 'lt', ';', 'JPI', '>', ...]
# ['MEDITRUST', '&', 'lt', ';', 'MTRUS', '>', 'RAISES', ...]
# ['MONSANTO', '&', 'lt', ';', 'MTC', '>', 'UNIT', ...]
# ['STATUS', 'GAME', 'CORP', '&', 'lt', ';', 'STGM', '>', ...]
# ['UNIVERSAL', 'FOODS', 'CORP', '&', 'lt', ';', 'UFC', ...]
# ['BETZ', 'LABORATORIES', 'INC', '&', 'lt', ';', 'BETZ', ...]
# ['NORTHWESTERN', 'NATIONAL', 'LIFE', '&', 'lt', ';', ...]
# ['GRAIN', 'SHIPS', 'WAITING', 'AT', 'NEW', 'ORLEANS', ...]
# ['FOOTHILL', '&', 'lt', ';', 'FGI', '>,', 'SIERRITA', ...]
# ['FIRST', 'FEDERAL', 'OF', 'MICHIGAN', '&', 'lt', ';', ...]
# ['COLONIAL', 'BANCGROUP', '&', 'lt', ';', 'CLBGA', '>', ...]
# ['FAB', 'INDUSTRIES', 'INC', '&', 'lt', ';', 'FIT', ...]
# ['EC', 'COMMISSION', 'AUTHORISED', 'TO', 'BUY', ...]
# ['JAPAN', 'BUYS', '5', ',', '000', 'TONNES', ...]
# ['NORTHERN', 'TRUST', 'CORP', '&', 'lt', ';', 'NTRS', ...]
# ['COLOMBIA', 'JAN', 'EXPORTS', 'UP', 'BUT', 'COFFEE', ...]
# ['LONDON', 'GRAIN', 'FREIGHTS', '27', ',', '000', ...]
# ['LONDON', 'SUGAR', 'FREIGHTS', 'TBN', '14', ',', '00', ...]
# ['LONDON', 'GRAIN', 'FREIGHT', 'ENQUIRIES', 'Antwerp', ...]
# ['HOME', 'SAVINGS', 'BANK', '&', 'lt', ';', 'HMSB', ...]
# ['AMOSKEAG', 'BANK', 'SHARES', 'INC', '&', 'lt', ';', ...]
# ['MSR', 'EXPLORATION', 'LTD', '&', 'lt', ';', 'MSR', ...]
# ['SOUTHMARK', '&', 'lt', ';', 'SM', '>', 'TO', 'OFFER', ...]
# ['EXPORTS', 'OTHER', 'THAN', 'COFFEE', 'RISE', ...]
# ['TAFT', 'BROADCASTING', '&', 'lt', ';', 'TFB', '>', ...]
# ['U', '.', 'S', '.', 'MARCH', 'RETAIL', 'SALES', 'CUT', ...]
# ['FIRST', 'INTERSTATE', 'EXPECTS', 'BRAZIL', ',', ...]
# ['MOROCCO', 'TENDERS', 'FOR', '55', ',', '000', ...]
# ['MIDLANTIC', 'CORP', '&', 'lt', ';', 'MIDL', '>', ...]
# ['COMMUNITY', 'BANK', 'SYSTEM', 'INC', '&', 'lt', ';', ...]
# ['FITCHBURG', 'GAS', '&', 'lt', ';', 'FGE', '>', ...]
# ['NORTHERN', 'TRUST', '&', 'lt', ';', 'NTRS', '>', ...]
# ['DOE', 'RUN', 'RAISES', 'LEAD', 'PRICE', '0', '.', ...]
# ['SPAIN', "'", 'S', 'FOREIGN', 'RESERVES', 'RISE', ...]
# ['&', 'lt', ';', 'SULPETRO', 'LTD', '>', '1ST', 'QTR', ...]
# ['WESTERN', 'FEDERAL', 'SAVINGS', 'BANK', '&', 'lt', ...]
# ['FINAL', 'TEST', 'INC', '&', 'lt', ';', 'FNLT', '>', ...]
# ['PROTECTIVE', 'LIFE', '&', 'lt', ';', 'PROT', '>', ...]
# ['A', '.', 'O', '.', 'SMITH', 'CORP', '&', 'lt', ';', ...]
# ['CENTRAL', 'BANCORP', 'INC', '&', 'lt', ';', 'CBAN', ...]
# ['&', 'lt', ';', 'EMCOR', '>', 'COMPLETES', 'SALE', ...]
# ['VLSI', 'TECHNOLOGY', 'INC', '&', 'lt', ';', 'VLSI', ...]
# ['BELGIAN', 'CURRENT', 'ACCOUNT', 'SURPLUS', 'WIDENS', ...]
# ['SILICON', 'SYSTEMS', 'INC', '&', 'lt', ';', 'SLCN', ...]
# ['DISEASE', 'PUTS', 'ZIMBABWE', 'BEEF', 'EXPORTS', ...]
# ['SHAWMUT', 'CORP', '&', 'lt', ';', 'SHAS', '>', '1ST', ...]
# ['MINNTECH', '&', 'lt', ';', 'MNTX', '>', 'SEES', ...]
# ['GORDEX', 'MINERALS', 'LOCATES', 'GOLD', 'DEPOSITS', ...]
# ['U', '.', 'S', '.', 'CONGRESSMAN', 'INTRODUCES', ...]
# ['CANADA', '91', '-', 'DAY', 'T', '-', 'BILLS', ...]
# ['REPUBLIC', 'SAVINGS', 'AND', 'LOAN', '&', 'lt', ';', ...]
# ['SOUTHMARK', '&', 'lt', ';', 'SM', '>', 'TO', 'ISSUE', ...]
# ['WALL', 'STREET', 'STOCKS', '/', 'UAL', 'INC', '&', ...]
# ['GORDEX', 'MINERALS', 'LOCATES', 'CANADA', 'GOLD', ...]
# ['CANADIAN', 'BANK', 'RATE', 'RISES', 'IN', 'WEEK', ...]
# ['CONSENSUS', 'SEEN', 'ON', 'TIN', 'PACT', 'EXTENSION', ...]
# ['SLATER', 'ELECTRIC', 'INC', '&', 'lt', ';', 'SLAT', ...]
# ['SOUTH', 'JERSEY', 'INDUSTRIES', 'INC', '&', 'lt', ...]
# ['CITY', 'NATIONAL', 'CORP', '&', 'lt', ';', 'CTYN', ...]
# ['ALLIED', 'BANKSHARES', 'INC', '&', 'lt', ';', 'ABGA', ...]
# ['ROYAL', 'DUTCH', '&', 'lt', ';', 'RD', '>', 'UNIT', ...]
# ['MAGMA', 'RAISES', 'COPPER', 'PRICE', '0', '.', '25', ...]
# ['FIRST', 'BANK', 'SYSTEM', 'INC', '&', 'lt', ';', ...]
# ['CENTERRE', 'BANCORP', '&', 'lt', ';', 'CTBC', '>', ...]
# ['SEA', 'GALLEY', 'STORES', 'INC', '&', 'lt', ';', ...]
# ['EGYPT', 'CANCELS', 'WHEAT', 'TENDER', 'Egypt', 'has', ...]
# ['HOUSE', 'PANEL', 'WANTS', 'PENTAGON', 'MANAGE', 'U', ...]
# ['CANADA', 'TRADE', 'RISE', 'SEEN', 'AS', 'START', ...]
# ['FIRST', 'BANK', '&', 'lt', ';', 'FBS', '>', 'SEES', ...]
# ['USDA', 'ESTIMATES', '1986', '/', '87', 'USSR', ...]
# ['USDA', 'ESTIMATES', '1986', 'SOVIET', 'GRAIN', ...]
# ['USDA', '-', 'U', '.', 'S', '.', '1986', '/', '87', ...]
# ['USDA', '1986', '/', '87', 'U', '.', 'S', '.', ...]
# ['USDA', 'ESTIMATES', '1986', '/', '87', 'ORANGE', ...]
# ['VORNADO', 'INC', '&', 'lt', ';', 'VNO', '>', '4TH', ...]
# ['FIRST', 'UNION', 'CORP', 'FIRST', 'QTR', 'SHR', '71', ...]
# ['U', '.', 'S', '.', 'SUPPLY', '/', 'DEMAND', ...]
# ['U', '.', 'S', '.', 'CITRUS', 'CROP', 'ESTIMATE', ...]
# ['USDA', 'ORANGE', 'JUICE', 'YIELD', 'ESTIMATE', 'The', ...]
# ['USSR', 'ADDS', 'U', '.', 'S', '.', 'CORN', 'TO', ...]
# ['USDA', 'SPRING', 'POTATO', 'ESTIMATES', 'The', 'U', ...]
# ['USDA', 'REVISES', '1986', 'SUMMER', 'POTATOES', ...]
# ['USDA', 'DETAILS', 'FREE', 'GRAIN', 'STOCKS', 'UNDER', ...]
# ['CLEVITE', '&', 'lt', ';', 'CLEV', '>', 'AMENDS', ...]
# ['USDA', 'ESTIMATES', 'SOVIET', 'WHEAT', ',', 'COARSE', ...]
# ['WHEAT', 'BY', 'CLASS', 'BREAKDOWN', 'The', 'U', '.', ...]
# ['USDA', 'FORECASTS', 'BRAZIL', '/', 'ARGENTINE', ...]
# ['USDA', 'ESTIMATES', 'ARGENTINE', 'COARSE', 'GRAIN', ...]
# ['STOP', 'AND', 'SHOP', 'COS', 'IN', '2', '-', 'FOR', ...]
# ['USDA', 'ESTIMATES', 'AUSTRALIA', 'WHEAT', 'CROP', ...]
# ['USDA', 'ESTIMATES', 'CHINA', 'WHEAT', 'The', 'U', ...]
# ['USDA', 'ESTIMATES', 'CANADIAN', 'CROPS', 'The', 'U', ...]
# ['NET', 'CHANGE', 'IN', 'EXPORT', 'COMMITMENTS', '--', ...]
# ['HOUSE', 'PANEL', 'WANTS', 'PENTAGON', 'MANAGE', 'U', ...]
# ['USDA', 'ESTIMATES', 'EUROPEAN', 'COMMUNITY', 'CROPS', ...]
# ['U', '.', 'S', '.', 'SUPPLY', '/', 'DEMAND', ...]
# ['USDA', 'ESTIMATES', 'USSR', 'COTTON', 'CROP', 'The', ...]
# ['USDA', 'ESTIMATES', 'SOUTH', 'AFRICA', 'CORN', ...]
# ['STOP', 'AND', 'SHOP', 'COS', '&', 'lt', ';', 'SHP', ...]
# ['NATIONAL', 'BEVERAGE', 'TO', 'ACQUIRE', 'FAYGO', ...]
# ['AUDIO', '/', 'VIDEO', 'AFFILIATES', '&', 'lt', ';', ...]
# ['FLUOROCARBON', '&', 'lt', ';', 'FCBN', '>', 'BUYS', ...]
# ['FIRST', 'UNION', 'CORP', '&', 'lt', ';', 'FUNC', '>', ...]
# ['FINANCIAL', 'NEWS', 'NETWORK', 'INC', '&', 'lt', ';', ...]
# ['FIRST', 'COLONIAL', 'BANKSHARES', 'CORP', '&', 'lt', ...]
# ['SEASONAL', 'EXPORTS', 'REPORTED', 'BY', 'U', '.', ...]
# ['HAWAIIAN', 'ELECTRIC', '&', 'lt', ';', 'HE', '>', ...]
# ['SOVIET', 'UNION', 'TO', 'IMPORT', 'MORE', 'GRAIN', ...]
# ['DISNEY', 'FAMILY', 'MAKES', 'BID', 'FOR', 'HOLLY', ...]
# ['U', '.', 'S', '.', 'EXPORTERS', 'REPORT', '200', ',', ...]
# ['UNIVERSAL', 'HEALTH', 'REALTY', '&', 'lt', ';', ...]
# ['FROST', 'AND', 'SULLIVAN', 'INC', '&', 'lt', ';', ...]
# ['C', '.', 'O', '.', 'M', '.', 'B', '.', '&', 'lt', ...]
# ['RAI', 'RESEARCH', 'CORP', '&', 'lt', ';', 'RAC', '>', ...]
# ['CENTEL', '&', 'lt', ';', 'CNT', '>', 'COMPLETES', ...]
# ['JAMES', 'RIVER', 'CORP', '&', 'lt', ';', 'JR', '>', ...]
# ['THREE', 'D', 'DEPARTMENTS', 'INC', '&', 'lt', ';', ...]
# ['U', '.', 'S', '.', 'EXPORTERS', 'REPORT', '300', ',', ...]
# ['U', '.', 'S', '.', 'EXPORTERS', 'REPORT', '100', ',', ...]
# ['WORLD', 'SUPPLY', '/', 'DEMAND', 'ESTIMATES', ...]
# ['ADAMS', 'EXPRESS', 'CO', '&', 'lt', ';', 'ADX', '>', ...]
# ['PETROLEUM', 'AND', 'RESOURCES', 'CORP', '&', 'lt', ...]
# ['CORN', 'SUPPLY', '/', 'DEMAND', 'BY', 'COUNTRY', ...]
# ['USDA', 'REPORTS', 'EXPORT', 'SALES', 'ACTIVITY', ...]
# ['INTERNATIONAL', 'AMERICAN', '&', 'lt', ';', 'HOME', ...]
# ['SONY', 'CHAIRMAN', 'FORECASTS', 'LOWER', 'PROFITS', ...]
# ['COARSE', 'GRAIN', 'SUPPLY', '/', 'DEMAND', 'BY', ...]
# ['EXPORT', 'BONUS', 'WHEAT', 'FOR', 'JORDAN', '--', ...]
# ['ARGENTINE', '1986', '/', '87', 'GRAIN', 'OILSEED', ...]
# ['WINN', 'ENTERPRISES', '&', 'lt', ';', 'WNN', '>', ...]
# ['NATIONAL', 'BEVERAGE', 'TO', 'ACQUIRE', 'FAYGO', '&', ...]
# ['SOYBEAN', 'SUPPLY', '/', 'DEMAND', 'BY', 'COUNTRY', ...]
# ['SOYBEAN', 'MEAL', 'SUPPLY', '/', 'DEMAND', 'BY', ...]
# ['SOYBEAN', 'OIL', 'SUPPLY', '/', 'DEMAND', 'BY', ...]
# ['ROYAL', 'DUTCH', '(', 'RD', ')', 'UNIT', 'TO', ...]
# ['COTTON', 'SUPPLY', '/', 'DEMAND', 'BY', 'COUNTRY', ...]
# ['EXPORT', 'BONUS', 'WHEAT', 'FLOUR', 'TO', 'IRAQ', ...]
# ['RICE', 'SUPPLY', '/', 'DEMAND', 'FOR', 'THAILAND', ...]
# ['USDA', 'FLORIDA', 'ORANGE', 'REPORT', 'CONSIDERED', ...]
# ['JAMES', 'RIVER', 'CORP', '&', 'lt', ';', 'JR', '>', ...]
# ['NORANDA', 'BEGINS', 'SALVAGE', 'OPERATIONS', 'AT', ...]
# ['NEWHALL', 'INVESTMENT', 'PROPERTIES', '&', 'lt', ';', ...]
# ['NEWHALL', 'RESOURCES', '&', 'lt', ';', 'NR', '>', ...]
# ['WESTINGHOUSE', 'ELECTRIC', 'CORP', '1ST', 'QTR', ...]
# ['U', '.', 'S', '.', 'OIL', 'DEPENDENCY', 'SEEN', ...]
# ['GRAIN', 'SHIPS', 'LOADING', 'AT', 'PORTLAND', ...]
# ['WESTINGHOUSE', 'ELECTRIC', 'CORP', '&', 'lt', ';', ...]
# ['CCC', 'GUARANTEES', 'TO', 'IRAQ', 'SWITCHED', '--', ...]
# ['NEW', 'YORK', 'BUSINESS', 'LOANS', 'FALL', '1', '.', ...]
# ['N', '.', 'Y', '.', 'BANK', 'DISCOUNT', 'BORROWINGS', ...]
# ['NATIONAL', 'AVERAGE', 'PRICES', 'FOR', 'FARMER', '-', ...]
# ['U', '.', 'S', '.', 'WEEKLY', 'SOYBEAN', 'CRUSH', ...]
# ['FUNDAMENTAL', 'BROKERS', 'BUYS', 'PART', 'OF', 'MKI', ...]
# ['NEWHALL', 'INVESTMENT', '&', 'lt', ';', 'NIP', '>', ...]
# ['FCOJ', 'MOVEMENT', '4', ',', '496', ',', '533', ...]
# ['NATIONAL', 'HERITAGE', '&', 'lt', ';', 'NHER', '>', ...]
# ['OHIO', 'MATTRESS', '&', 'lt', ';', 'OMT', '>', ...]
# ['LA', 'LAND', '&', 'lt', ';', 'LLX', '>,', 'DU', ...]
# ['PATIENT', '&', 'lt', ';', 'PTI', '>', 'CONSIDERING', ...]
# ['NAPCO', '&', 'lt', ';', 'NPCO', '>', 'MANAGEMENT', ...]
# ['BANKS', 'OF', 'MID', '-', 'AMERICA', 'INC', '&', ...]
# ['MCDONNELL', 'DOUGLAS', '&', 'lt', ';', 'MD', '>', ...]
# ['WORLD', 'MARKET', 'PRICE', 'FOR', 'UPLAND', 'COTTON', ...]
# ['USDA', 'COMMENTS', 'ON', 'EXPORT', 'SALES', 'REPORT', ...]
# ['U', '.', 'S', '.', 'M', '-', '1', 'MONEY', 'SUPPLY', ...]
# ['FED', 'SAYS', 'U', '.', 'S', '.', 'DISCOUNT', ...]
# ['U', '.', 'S', '.', 'BANK', 'NET', 'FREE', 'RESERVES', ...]
# ['WESTINGHOUSE', 'ELECTRIC', '&', 'lt', ';', 'WX', '>', ...]
# ['BSD', 'BANCORP', '&', 'lt', ';', 'BSD', '>', '1ST', ...]
# ['GATEWAY', 'COMMUNICATIONS', 'INC', '&', 'lt', ';', ...]
# ['BAKER', 'COMMUNICATIONS', 'INC', '&', 'lt', ';', ...]
# ['EASTOVER', 'CORP', '&', 'lt', ';', 'EASTS', '>', ...]
# ['U', '.', 'S', '.', 'BANK', 'DISCOUNT', 'BORROWINGS', ...]
# ['NORANDA', 'BEGINS', 'MURDOCHVILLE', 'MINE', ...]
# ['U', '.', 'S', '.', 'M', '-', '1', 'MONEY', 'SUPPLY', ...]
# ['BEVIS', '&', 'lt', ';', 'BEVI', '>', 'RECEIVES', ...]
# ['JACOR', '&', 'lt', ';', 'JCOR', '>', 'TO', 'BUY', ...]
# ['ASSETS', 'OF', 'U', '.', 'S', '.', 'MONEY', 'FUNDS', ...]
# ['POLYCAST', '&', 'lt', ';', 'PTCC', '>', 'REDUCES', ...]
# ['GRAIN', 'SHIPMENTS', 'TO', 'THE', 'USSR', '--', ...]
# ['HOSPITAL', 'CORP', 'SAYS', 'IT', 'RECEIVED', '47', ...]
# ['BEVERLY', 'ENTERPRISES', '&', 'lt', ';', 'BEV', '>', ...]
# ['TREASURY', "'", 'S', 'BAKER', 'SAYS', 'FLOATING', ...]
# ['CRUDE', 'OIL', 'NETBACKS', 'UP', 'SHARPLY', 'IN', ...]
# ['TREASURY', "'", 'S', 'BAKER', 'SAYS', 'SYSTEM', ...]
# ['NERCI', '&', 'lt', ';', 'NER', '>', 'UNIT', 'CLOSES', ...]
# ['U', '.', 'S', '.', 'DOLLAR', 'LOSSES', 'PROPEL', ...]
# ['EGYPT', 'SEEKING', '500', ',', '000', 'TONNES', ...]
# ['TRUSTCORP', 'INC', '&', 'lt', ';', 'TTCO', '>', ...]
# ['9', '-', 'APR', '-', '1987', '17', ':', '28', ':', ...]
# ['NAPA', 'VALLEY', 'BANCORP', '&', 'lt', ';', 'NVBC', ...]
# ['INTERNATIONAL', 'POWER', 'MACHINES', '&', 'lt', ';', ...]
# ['GREAT', 'AMERICAN', 'MGMT', '&', 'lt', ';', 'GAMI', ...]
# ['RAI', 'RESEARCH', 'CORP', '&', 'lt', ';', 'RAC', '>', ...]
# ['MOORE', '&', 'lt', ';', 'MCL', '>', 'SEES', ...]
# ['FIRM', 'HAS', '14', '.', '8', 'PCT', 'OF', ...]
# ['PARTNERSHIP', 'BUYS', 'IPCO', '&', 'lt', ';', 'IHS', ...]
# ['DELMED', 'INC', '&', 'lt', ';', 'DMD', '>', 'YEAR', ...]
# ['CADILLAC', 'FAIRVIEW', 'SAYS', 'IT', 'HAS', ...]
# ['CADILLAC', 'FAIRVIEW', 'SAYS', 'IT', 'RECEIVED', ...]
# ['9', '-', 'APR', '-', '1987', '18', ':', '20', ':', ...]
# ['WINTERHALTER', '&', 'lt', ';', 'WNTLC', '>', ...]
# ['&', 'lt', ';', 'AMERICAN', 'EAGLE', 'PETROLEUMS', ...]
# ['CHILEAN', 'TRADE', 'SURPLUS', 'NARROWS', 'SLIGHTLY', ...]
# ['ANALYSTS', 'DOUBT', 'FED', 'FIRMED', 'DESPITE', ...]
# ['VALEX', 'PETROLEUM', 'INC', '&', 'lt', ';', 'VALP', ...]
# ['N', '.', 'Z', '.', 'TRADING', 'BANK', 'DEPOSIT', ...]
# ['BANK', 'OF', 'JAPAN', 'INTERVENES', 'TO', 'BUY', ...]
# ['DOLLAR', 'OPENS', 'AT', 'RECORD', 'TOKYO', 'LOW', ...]
# ['DOLLAR', 'OPENS', 'AT', 'TOKYO', 'RECORD', 'LOW', ...]
# ['DOLLAR', 'FALLS', 'BELOW', '143', 'YEN', 'IN', ...]
# ['ARGENTINE', 'GRAIN', 'MARKET', 'REVIEW', 'The', ...]
# ['U', '.', 'S', '.', 'MARKETS', 'OFFER', 'GLIMPSE', ...]
# ['AVERAGE', 'YEN', 'CD', 'RATES', 'FALL', 'IN', ...]
# ['JAPAN', 'HAS', 'NO', 'PLANS', 'TO', 'CUT', ...]
# ['AUSTRALIAN', 'UNIONS', 'AND', 'NSW', 'GOVERNMENT', ...]
# ['ECUADOR', 'CRUDE', 'OIL', 'OUTPUT', 'TO', 'RESUME', ...]
# ['THAI', 'RICE', 'EXPORTS', 'FALL', 'IN', 'WEEK', 'TO', ...]
# ['JAPAN', 'SEES', 'MARGINAL', 'RISE', 'IN', 'EDIBLE', ...]
# ['INTEREST', 'RATE', 'DIFFERENTIALS', 'TOO', 'SMALL', ...]
# ['MOBIL', 'AUSTRALIA', 'REPORTS', '38', '.', '6', ...]
# ['JAPAN', 'WARNS', 'U', '.', 'S', '.', 'IT', 'MAY', ...]
# ['KUWAIT', 'INCREASES', 'STAKE', 'IN', 'SIME', 'DARBY', ...]
# ['SMUGGLING', 'BLAMED', 'FOR', 'CLOSURE', 'OF', ...]
# ['TAIWAN', 'ANNOUNCES', 'NEW', 'ROUND', 'OF', 'IMPORT', ...]
# ['BRITISH', 'MINISTER', 'SAYS', 'HE', 'WARNED', ...]
# ['YIELD', 'RISES', 'ON', '30', '-', 'DAY', 'SAMA', ...]
# ['UGANDA', 'PULLS', 'OUT', 'OF', 'COFFEE', 'MARKET', ...]
# ['W', '.', 'GERMAN', 'COCOA', 'GRIND', 'UP', '2', '.', ...]
# ['DRY', 'SPELL', 'IN', 'PHILIPPINES', 'DAMAGES', ...]
# ['SPANISH', 'UNEMPLOYMENT', 'FALLS', 'SLIGHTLY', 'IN', ...]
# ['HUNGARY', 'RAISES', 'PRICES', 'IN', 'EFFORT', 'TO', ...]
# ['BANK', 'OF', 'JAPAN', 'ACTIVELY', 'BUYING', ...]
# ['CHINA', 'WANTS', 'TO', 'BUY', '5', ',', '000', ...]
# ['AUSTRALIAN', 'GOVERNMENT', 'MUST', 'CUT', 'SPENDING', ...]
# ['ELECTROLYTIC', 'REFINING', 'LOWERS', 'COPPER', ...]
# ['JAPAN', 'CENTRAL', 'BANK', 'ACTIVELY', 'BUYS', ...]
# ['TEXACO', 'SEES', 'BUSINESS', 'LITTLE', 'HIT', 'BY', ...]
# ['PATON', 'REPORTS', 'U', '.', 'S', '.', 'GREEN', ...]
# ['WESTERN', 'MINING', 'SELLS', 'ACM', 'STAKE', ...]
# ['YUGOSLAV', 'ECONOMY', 'WORSENED', 'IN', '1986', ',', ...]
# ['ANZ', 'BANK', 'SETS', 'ONE', '-', 'FOR', '-', 'TWO', ...]
# ['UAE', 'CENTRAL', 'BANK', 'CD', 'YIELDS', 'RISE', ...]
# ['CHINA', 'SULPHUR', '-', 'IRON', 'MINE', 'STARTS', ...]
# ['CHINA', ',', 'CHILE', 'TO', 'BUILD', 'COPPER', ...]
# ['SINGAPORE', 'EXTERNAL', 'TRADE', 'GAINS', '8', '.', ...]
# ['MALAYSIA', "'", 'S', '1986', 'MANUFACTURING', ...]
# ['OFFER', 'FOR', 'DOME', 'MAY', 'SHORT', '-', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'DEFICIT', ...]
# ['BANGLADESH', 'COST', 'OF', 'LIVING', 'INDEX', ...]
# ['ROTHMANS', 'DENIES', 'SHARE', 'SALE', 'SPECULATION', ...]
# ['TRADE', 'ISSUES', 'STRAINING', 'EC', "'", 'S', ...]
# ['MORGAN', 'CRUCIBLE', 'SAYS', 'PROSPECTS', 'ARE', ...]
# ['MORGAN', 'CRUCIBLE', 'PRETAX', 'PROFIT', 'RISES', ...]
# ['SWEDISH', 'INDUSTRIAL', 'PRODUCTION', 'RISES', ...]
# ['KENYA', 'DEVALUES', 'SHILLING', 'BY', '0', '.', '6', ...]
# ['AWB', 'CHAIRMAN', 'URGES', 'FARMERS', 'NOT', 'TO', ...]
# ['WILLIAMS', 'DETAILS', 'ACCEPTANCES', 'OF', 'NORCROS', ...]
# ['DUTCH', 'FEED', 'COMPOUNDER', 'STARTS', 'CASE', ...]
# ['CHINA', 'RAISES', 'GRAIN', 'PURCHASE', 'PRICES', ...]
# ['WEST', 'GERMAN', 'COCOA', 'GRINDINGS', 'WITHIN', ...]
# ['ST', '.', 'GOBAIN', 'UNIT', 'ISSUES', 'ECU', 'BOND', ...]
# ['COMMONWEALTH', 'BANK', 'CUTS', 'AUSTRALIA', 'PRIME', ...]
# ['HEPWORTH', 'SELLS', 'U', '.', 'S', '.', 'UNIT', 'TO', ...]
# ['BOND', 'CORP', 'TO', 'ACQUIRE', '80', 'PCT', 'OF', ...]
# ['INSTITUTES', 'DIVIDED', 'ON', 'OUTLOOK', 'FOR', ...]
# ['BLUE', 'ARROW', 'TO', 'BUY', 'U', '.', 'S', '.', ...]
# ['SAUDI', 'RIYAL', 'DEPOSITS', 'SURGE', 'ON', 'U', '.', ...]
# ['LONDON', 'GOLD', 'MORNING', 'FIX', 'HIGHEST', ...]
# ['BORG', '-', 'WARNER', 'AGREES', 'TO', 'BUYOUT', 'BY', ...]
# ['U', '.', 'K', '.', 'MARCH', 'PRODUCER', 'PRICES', ...]
# ['STATOIL', 'SEEKS', 'SHARE', 'IN', 'THAI', 'GAS', ...]
# ['CREDIT', 'COMMERCIAL', 'DE', 'FRANCE', 'SPLITS', ...]
# ['WEST', 'GERMAN', 'INSTITUTES', 'CALL', 'FOR', ...]
# ['Glaxo', 'pre', '-', 'tax', 'profit', '376', 'mln', ...]
# ['HILLSDOWN', 'BUYS', 'BEDDING', 'COMPANIES', 'FOR', ...]
# ['GLAXO', 'PROFITS', 'UP', 'SHARPLY', ',', 'DIVIDEND', ...]
# ['TAKEOVER', 'BATTLE', 'FOR', 'DOME', 'PETROLEUM', ...]
# ['BANK', 'OF', 'JAPAN', 'TO', 'SELL', '800', 'BILLION', ...]
# ['LME', 'CLARIFIES', 'NEW', 'ALUMINIUM', 'CONTRACT', ...]
# ['YIELD', 'ON', '91', '-', 'DAY', 'SAMA', 'DEPOSITS', ...]
# ['NORTH', 'YEMEN', 'BOUGHT', 'WHITE', 'SUGAR', 'AT', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'GIVEN', '75', ...]
# ['JAPAN', 'CENTRAL', 'BANK', 'ACTIVELY', 'BUYS', ...]
# ['CURRENCY', 'MOVES', 'MAY', 'BE', 'HURTING', 'WORLD', ...]
# ['SAUDI', 'ARABIA', 'SEEKING', 'RBD', 'PALM', 'OLEIN', ...]
# ['METAL', 'BULLETIN', 'ZINC', 'PRODUCER', 'PRICE', ...]
# ['U', '.', 'K', '.', 'PRODUCER', 'PRICES', 'SEEN', ...]
# ['BANGEMANN', 'REJECTS', 'CALL', 'FOR', 'EARLY', 'TAX', ...]
# ['ITALIAN', 'GDP', 'ROSE', '2', '.', '4', 'PCT', 'IN', ...]
# ['G', '-', '7', 'SEEMS', 'WORRIED', 'MARKETS', ...]
# ['INSTITUTES', 'SEE', 'NO', 'WEST', 'GERMAN', ...]
# ['DEPOSIT', 'GUARANTY', 'CORP', '&', 'lt', ';', 'DEPS', ...]
# ['COMPUTER', 'ASSOCIATES', '&', 'lt', ';', 'CA', '>', ...]
# ['KING', 'WORLD', 'PRODUCTIONS', 'INC', '&', 'lt', ';', ...]
# ['BLUE', 'CIRCLE', 'PROFITS', ',', 'DIVIDEND', 'RISE', ...]
# ['CRAZY', 'EDDIE', '&', 'lt', ';', 'CRZY', '>', 'MAY', ...]
# ['CRAZY', 'EDDIE', '&', 'lt', ';', 'CRZY', '>', 'SETS', ...]
# ['SIX', 'KILLED', 'IN', 'SOUTH', 'AFRICAN', 'MINE', ...]
# ['ZAMBIA', "'", 'S', 'KWACHA', 'FALLS', 'AT', 'WEEKLY', ...]
# ['U', '.', 'S', '.', 'SENATE', 'LEADER', 'CALLS', ...]
# ['OFFER', 'FOR', 'DOME', 'MAY', 'SHORT', '-', ...]
# ['SOSNOFF', 'RAISES', 'BID', 'FOR', 'CAESARS', 'WORLD', ...]
# ['COMPACT', 'VIDEO', 'INC', '&', 'lt', ';', 'CVSI', ...]
# ['NEWORLD', 'BANK', 'FOR', 'SAVINGS', '&', 'lt', ';', ...]
# ['USAIR', 'TO', 'BUY', '55', 'PCT', 'OF', '17', '.', ...]
# ['PAKISTAN', 'CONFIRMS', 'KENYA', 'TEA', 'IMPORT', ...]
# ['PORTUGUESE', 'ECONOMY', 'REMAINS', 'BUOYANT', ...]
# ['MERRILL', 'LYNCH', 'FIRST', 'QTR', 'SHR', 'ONE', ...]
# ['MERRILL', 'LYNCH', 'AND', 'CO', '&', 'lt', ';', ...]
# ['CORONA', '&', 'lt', ';', 'ICR', '.', 'TO', '>', ...]
# ['S', '.', 'ATLANTIC', '&', 'lt', ';', 'SOAF', '.', ...]
# ['HOME', 'FEDERAL', 'UPPER', 'EAST', 'TENNESSEE', '&', ...]
# ['U', '.', 'S', '.', 'FEEDER', 'STEER', 'PRICE', 'The', ...]
# ['COLUMBIA', 'GAS', '&', 'lt', ';', 'CG', '>', 'SEEKS', ...]
# ['HUNGARY', 'RAISES', 'PRICES', 'IN', 'EFFORT', 'TO', ...]
# ['P', '.', 'H', '.', 'GLATFELTER', 'CO', 'SAYS', 'IT', ...]
# ['FAMILY', 'HEALTH', 'SYSTEMS', 'INC', '&', 'lt', ';', ...]
# ['INTERNATIONAL', 'BUSINESS', 'MACHINES', 'CORP', '&', ...]
# ['USAIR', '&', 'lt', ';', 'U', '>', 'REPORTS', 'FINAL', ...]
# ['MORE', 'BRITISH', 'GOLD', 'ARTICLES', 'HALLMARKED', ...]
# ['SWISS', 'SIGHT', 'DEPOSITS', 'FALL', '4', '.', '64', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'GIVEN', ...]
# ['GOODYEAR', '&', 'lt', ';', 'GT', '>', 'PREDICTS', ...]
# ['HOG', 'AND', 'CATTLE', 'SLAUGHTER', 'GUESSTIMATES', ...]
# ['TRADE', 'ISSUES', 'STRAINING', 'EC', "'", 'S', ...]
# ['EC', 'COULD', 'DECIDE', 'ON', 'JAPAN', 'TRADE', ...]
# ['P', '.', 'H', '.', 'GLATFELTER', '&', 'lt', ';', ...]
# ['NCR', 'CORP', '1ST', 'QTR', 'SHR', '65', 'CTS', 'VS', ...]
# ['FIRST', 'MARATHON', '&', 'lt', ';', 'FMS', '.', 'A', ...]
# ['U', '.', 'S', '.', 'BANCORP', '&', 'lt', ';', 'USBC', ...]
# ['IBM', '&', 'lt', ';', 'IBM', '>', 'HAS', 'HIGHER', ...]
# ['ROTTERDAM', 'GRAIN', 'HANDLER', 'SAYS', 'PORT', ...]
# ['LINDBERG', 'CORP', '&', 'lt', ';', 'LIND', '>', ...]
# ['GERMAN', 'INSTITUTES', 'WARN', 'ON', 'MONEY', ...]
# ['NCR', 'CORP', '&', 'lt', ';', 'NCR', '>', '1ST', ...]
# ['GERMAN', 'PRODUCER', 'PRICES', 'FALL', '0', '.', '1', ...]
# ['USDA', 'CHANGES', 'LOW', 'PROTEIN', 'WHEAT', ...]
# ['FHLBB', 'CHANGES', 'SHORT', '-', 'TERM', 'DISCOUNT', ...]
# ['GALILEO', 'ELECTRO', '-', 'OPTICS', 'CORP', '&', ...]
# ['BOSTON', 'FIVE', '&', 'lt', ';', 'BFCS', '.', 'O', ...]
# ['COOPERVISION', '&', 'lt', ';', 'EYE', '>', 'FORMS', ...]
# ['COLOMBIA', 'JUNE', 'COFFEE', 'REGISTRATIONS', ...]
# ['CANADA', 'LEADING', 'INDICATOR', 'UP', '0', '.', '4', ...]
# ['SPANISH', 'MONEY', 'SUPPLY', 'GROWING', 'AT', ...]
# ['REEBOK', 'INTERNATIONAL', 'LIMITED', '&', 'lt', ';', ...]
# ['BLOUNT', 'INC', '&', 'lt', ';', 'BLT', '>', '4TH', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'GIVEN', ...]
# ['GIANT', 'BAY', '&', 'lt', ';', 'GBYLF', '>', 'IN', ...]
# ['BLUE', 'ARROW', 'TO', 'ACQUIRE', 'RICHARDS', ...]
# ['MERRY', '-', 'GO', '-', 'ROUND', '&', 'lt', ';', ...]
# ['ASARCO', 'UPS', 'U', '.', 'S', '.', 'LEAD', 'PRICE', ...]
# ['IRVING', 'BANK', 'CORP', '1ST', 'QTR', 'SHR', '1', ...]
# ['IRVING', 'BANK', 'CORP', '&', 'lt', ';', 'V', '>', ...]
# ['O', "'", 'SULLIVAN', 'CORP', '&', 'lt', ';', 'OSL', ...]
# ['FRENCH', '13', '-', 'WEEK', 'T', '-', 'BILL', ...]
# ['PARK', 'COMMUNICATIONS', 'INC', '&', 'lt', ';', ...]
# ['NVHOMES', '&', 'lt', ';', 'NVH', '>', 'SETS', ...]
# ['13', '-', 'APR', '-', '1987', '13', '-', 'APR', '-', ...]
# ...
# ['SNC', 'GROUP', 'EXPECTS', 'HIGHER', '1987', ...]
# ['MINE', 'SAFETY', '&', 'lt', ';', 'MNES', '>', ...]
# ['MEDAR', 'INC', '&', 'lt', ';', 'MDXR', '>', '4TH', ...]
# ['MEDAR', '&', 'lt', ';', 'MDXR', '>', 'CHANGES', ...]
# ['U', '.', 'S', '.', 'SECURITIES', 'INDUSTRY', 'ASSN', ...]
# ['CHEMFIX', 'TECHNOLOGIES', 'INC', '&', 'lt', ';', ...]
# ['ALLIS', '-', 'CHALMERS', '&', 'lt', ';', 'AH', '>', ...]
# ['FLORIDA', 'EMPLOYERS', 'INSURANCE', 'CO', '&', 'lt', ...]
# ['SHELL', 'OIL', 'GETS', '104', '.', '3', 'MLN', 'DLR', ...]
# ['NIKE', 'INC', '&', 'lt', ';', 'NIKE', '>', '3RD', ...]
# ['ZENITH', 'NATIONAL', 'INSURANCE', '&', 'lt', ';', ...]
# ['REDKIN', 'LABORATORIES', 'INC', '&', 'lt', ';', ...]
# ['3', '-', 'MAR', '-', '1987', '07', ':', '35', ':', ...]
# ['COOPERVISION', 'INC', '&', 'lt', ';', 'EYE', '>', ...]
# ['U', '.', 'S', '.', 'SECURITIES', 'GROUP', 'BACKS', ...]
# ['TEXACO', '&', 'lt', ';', 'TX', '>', 'RESERVES', ...]
# ['INT', "'", 'L', 'MINERALS', 'PROJECT', 'TO', 'BOOST', ...]
# ['PULITZER', 'PUBLISHING', 'CO', '&', 'lt', ';', ...]
# ['FEDERAL', 'CO', '&', 'lt', ';', 'FFF', '>', 'SETS', ...]
# ['SOUTHWESTERN', 'BELL', '&', 'lt', ';', 'SBC', '>', ...]
# ['BRAZIL', 'WANTS', 'TO', 'INCREASE', 'STEEL', ...]
# ['LEAR', 'SIEGLER', 'HOLDING', 'CORP', 'PLANS', 'TO', ...]
# ['VARITY', 'CORP', 'YEAR', 'SHR', 'LOSS', '21', 'CTS', ...]
# ['NORDSON', '&', 'lt', ';', 'NDSN', '>', 'SETS', '3', ...]
# ['INVESTMENT', 'FIRMS', 'CUT', 'CYCLOPS', '&', 'lt', ...]
# ['HK', 'HOTELS', 'SOARS', 'ON', 'TAKEOVER', ...]
# ['BALDRIGE', 'SEES', 'U', '.', 'S', '.', 'TRADE', ...]
# ['BALDRIGE', 'SEES', 'U', '.', 'S', '.', 'TRADE', ...]
# ['NORMAL', 'WORK', 'RESUMES', 'AT', 'NEW', 'ZEALAND', ...]
# ['VARITY', 'CORP', '&', 'lt', ';', 'VAT', '>', '4TH', ...]
# ['INDIANA', 'FEDERAL', '&', 'lt', ';', 'IFSL', '>', ...]
# ['LEAR', '-', 'SIEGLER', 'HOLDING', 'TO', 'DIVEST', ...]
# ['RUBBERMAID', '&', 'lt', ';', 'RBD', '>', 'COMPLETES', ...]
# ['CRYSTAL', 'OIL', 'CO', '&', 'lt', ';', 'COR', '>', ...]
# ['CHEMFIX', 'TECHNOLOGIES', '&', 'lt', ';', 'CFIX', ...]
# ['FEDERAL', '-', 'MOGUL', 'CORP', '&', 'lt', ';', ...]
# ['IOWA', 'RESOURCES', 'INC', '&', 'lt', ';', 'IOR', ...]
# ['EIA', 'SAYS', 'DISTILLATE', 'STOCKS', 'OFF', '3', ...]
# ['U', '.', 'S', '.', 'HOME', 'RESALES', 'UP', 'IN', ...]
# ['LOWER', 'U', '.', 'S', '.', 'SOYBEAN', 'LOAN', ...]
# ['FIDUCIARY', 'TRUST', 'CO', 'IN', 'FIVE', '-', 'FOR', ...]
# ['MODULAIRE', '&', 'lt', ';', 'MODX', '>', 'BUYS', ...]
# ['LA', 'QUINTA', 'MOTOR', 'INNS', 'INC', '&', 'lt', ...]
# ['KANSAS', 'CITY', 'SOUTHERN', 'INDUSTRIES', 'SAYS', ...]
# ['U', '.', 'S', '.', 'CHIPMAKERS', 'URGE', 'SANCTIONS', ...]
# ['BRYSON', 'PAYS', '5', '.', '4', 'MLN', 'DLRS', 'FOR', ...]
# ['RECENT', 'U', '.', 'S', '.', 'OIL', 'DEMAND', 'UP', ...]
# ['FED', 'APPROVES', 'CHEMICAL', 'BANK', 'ACQUISITION', ...]
# ['KANSAS', 'CITY', '&', 'lt', ';', 'KSU', '>', 'READY', ...]
# ['GENCORP', '&', 'lt', ';', 'GY', '>', 'BID', 'COULD', ...]
# ['UNOCAL', '&', 'lt', ';', 'UCL', '>', 'PLANS', ...]
# ['FED', 'APPROVES', 'CHEMICAL', 'NEW', 'YORK', '&', ...]
# ['VARITY', '&', 'lt', ';', 'VAT', '>', 'SEES', ...]
# ['CAMPBELL', 'RESOURCES', '&', 'lt', ';', 'CCH', '>', ...]
# ['METROBANC', '&', 'lt', ';', 'MTBC', '>', ...]
# ['PLAINS', 'RESOURCES', 'INC', '&', 'lt', ';', 'PLNS', ...]
# ['PENNZOIL', '(', 'PZL', ')', 'WILLING', 'TO', ...]
# ['GV', 'MEDICAL', 'INC', '&', 'lt', ';', 'GVMI', '>', ...]
# ['IBC', 'PRESIDENT', 'NOT', 'TO', 'ATTEND', 'ICO', ...]
# ['EXCHANGE', 'RATE', 'BILL', 'CLEARS', 'U', '.', 'S', ...]
# ['U', '.', 'S', '.', 'CHIPMAKERS', 'URGE', 'SANCTIONS', ...]
# ['CLABIR', '&', 'lt', ';', 'CLG', '>,', 'AMBRIT', '&', ...]
# ['COST', 'OF', 'PIK', 'CERTIFICATES', 'TO', 'BE', ...]
# ['DAILY', 'TELEGRAPH', 'IN', 'DEAL', 'WITH', 'NEWS', ...]
# ['FRIEDMAN', 'INDUSTRIES', 'INC', '&', 'lt', ';', ...]
# ['LATIN', 'OIL', 'PRODUCERS', 'TO', 'MEET', 'IN', ...]
# ['AUSTRALIAN', 'RESERVE', 'BANK', 'CUTS', 'REDISCOUNT', ...]
# ['GENOVA', '&', 'lt', ';', 'GNVA', '>', 'SIGNS', ...]
# ['PENOBSCOT', 'SHOE', 'CO', '&', 'lt', ';', 'PSO', '>', ...]
# ['ASHTON', '-', 'TATE', '&', 'lt', ';', 'TATE', '>', ...]
# ['DAUSTER', 'SAYS', 'NO', 'CHANGE', 'IN', 'BRAZIL', ...]
# ['EXCHANGE', 'RATE', 'BILL', 'CLEARS', 'U', '.', 'S', ...]
# ['CONSOLIDATE', 'CAPITAL', 'TRUST', '&', 'lt', ';', ...]
# ['TREASURY', "'", 'S', 'BAKER', 'SAYS', 'HE', 'STANDS', ...]
# ['BAKER', 'SAYS', 'HE', 'STANDS', 'BY', 'PARIS', ...]
# ['NEITHER', 'SIDE', 'OPTIMISTIC', 'ON', 'ROTTERDAM', ...]
# ['BAKER', 'SEES', '15', 'TO', '20', 'BILLION', 'DLR', ...]
# ['Sumita', 'says', 'further', 'yen', 'rise', 'would', ...]
# ['Sumita', 'says', 'major', 'nations', 'will', ...]
# ['ASCS', 'TERMINAL', 'MARKET', 'VALUES', 'FOR', 'PIK', ...]
# ['N', '.', 'Z', '.', 'MONEY', 'SUPPLY', 'RISES', '2', ...]
# ['FURTHER', 'YEN', 'RISE', 'WOULD', 'HURT', 'JAPAN', ...]
# ['EC', 'LINKS', 'AGRICULTURAL', 'TRADE', 'TALKS', 'TO', ...]
# ['VIETNAM', "'", 'S', 'ARMY', 'ORDERED', 'TO', 'GROW', ...]
# ['LINDE', 'TURNOVER', 'UP', 'IN', 'FIRST', 'TWO', ...]
# ['LINDE', 'AG', '&', 'lt', ';', 'LING', '.', 'F', '>', ...]
# ['UNILEVER', 'IMPROVES', 'IN', 'MOST', 'SECTORS', ...]
# ['TRADE', 'SURPLUS', 'CUT', 'WOULD', 'BENEFIT', ...]
# ['GULF', 'ESCORTS', 'STILL', 'UNDER', 'DISCUSSION', ...]
# ['U', '.', 'S', '.', 'LEADING', 'INDICATORS', 'FELL', ...]
# ['MIYAZAWA', 'SAYS', 'MAJOR', 'NATIONS', 'ACTING', ...]
# ['Hoechst', 'AG', '1986', 'world', 'group', 'pretax', ...]
# ['BANK', 'OF', 'FRANCE', 'LAUNCHES', 'MONEY', 'MARKET', ...]
# ['HOECHST', 'AG', '&', 'lt', ';', 'HFAG', '.', 'F', ...]
# ['GERMAN', 'TRADE', ',', 'CURRENT', 'ACCOUNT', 'DATA', ...]
# ['BANK', 'OF', 'FRANCE', 'LAUNCHES', 'MONEY', 'MARKET', ...]
# ['BP', 'says', 'it', 'will', 'tender', 'for', ...]
# ['BP', 'TO', 'OFFER', '7', '.', '4', 'BILLION', 'DLRS', ...]
# ['HOECHST', 'RAISES', 'PROFITS', 'ON', 'LOWER', ...]
# ['Danish', 'overnight', 'money', 'market', 'rate', ...]
# ['BHP', 'NET', 'SEEN', 'AROUND', '600', 'MLN', 'DLRS', ...]
# ['BP', 'units', 'seek', 'five', 'billion', 'dlr', ...]
# ['INDIAN', 'PLANT', 'SIGNS', 'FIRST', 'ALUMINA', ...]
# ['U', '.', 'S', '.', 'LEADING', 'INDEX', 'FELL', '1', ...]
# ['LUCAS', 'INDUSTRIES', 'PLC', '&', 'lt', ';', 'LUCS', ...]
# ['BP', 'UNITS', 'SEEK', 'FIVE', 'BILLION', 'DLR', ...]
# ['CLUB', 'MEDITERRANEE', '&', 'lt', ';', 'CMI', '.', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'LIQUIDITY', ...]
# ['EC', 'SUGAR', 'TENDER', 'SEEN', 'AS', 'FURTHER', ...]
# ['German', 'Feb', 'current', 'account', 'surplus', '6', ...]
# ['German', 'February', 'trade', 'surplus', '10', '.', ...]
# ['GERMAN', 'CURRENT', 'ACCOUNT', 'SURPLUS', 'WIDENS', ...]
# ['KEATING', 'REVISES', 'DOWN', 'AUSTRALIAN', 'GROWTH', ...]
# ['TAIWAN', "'", 'S', 'SAVINGS', 'AT', 'RECORD', 'HIGH', ...]
# ['SHORT', '-', 'DATED', 'SAUDI', 'RIYAL', 'RATES', ...]
# ['JAPAN', 'BEEF', 'PRICE', 'SUPPORT', 'CUT', 'WILL', ...]
# ['FOREIGN', 'FIRMS', 'HOPE', 'TO', 'JOIN', 'JAPAN', ...]
# ['U', '.', 'K', '.', 'OILMEAL', '/', 'VEG', 'OIL', ...]
# ['BURLINGTON', 'COAT', 'FACTORY', 'WAREHOUSE', 'CORP', ...]
# ['SIEMENS', 'SEES', 'SALES', 'NEAR', '52', 'BILLION', ...]
# ['KRUPP', 'HAS', 'SATISFACTORY', '1986', 'RESULTS', ...]
# ['NO', 'PESSIMISM', 'FOR', 'GERMAN', 'EXPORTERS', ',', ...]
# ['MONETARY', 'AUTHORITIES', 'SAID', 'TO', 'LOSE', ...]
# ['UK', 'FEB', 'TRADE', 'DEFICIT', '224', 'MLN', 'STG', ...]
# ['U', '.', 'K', '.', 'FEB', 'CUURENT', 'ACCOUNT', ...]
# ['MALAYSIAN', 'CENTRAL', 'BANK', 'SEES', 'HIGHER', ...]
# ['COFFEE', 'PRICE', 'FALL', 'SHORT', 'TERM', '-', ...]
# ['U', '.', 'K', '.', 'VISIBLE', 'TRADE', 'DEFICIT', ...]
# ['LUCAS', 'SEES', 'CONTINUED', 'GROWTH', 'IN', ...]
# ['IWC', 'ups', 'Soviet', 'grain', '1986', '/', '87', ...]
# ['IWC', 'lifts', '1986', '/', '87', 'world', 'wheat', ...]
# ['TRADE', 'SURPLUS', 'CUT', 'WOULD', 'BENEFIT', ...]
# ['COMMISSION', 'APPROVES', 'RAINBOW', '/', ...]
# ['GREENWOOD', 'RESOURCES', '&', 'lt', ';', 'GRRL', '>', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'FORECAST', ...]
# ['IWC', 'LIFTS', 'WORLD', 'GRAIN', 'OUTPUT', ...]
# ['BANK', 'OF', 'JAPAN', 'BUYS', 'SMALL', 'QUANTITY', ...]
# ['U', '.', 'K', '.', 'TRADE', 'FIGURES', 'BUOY', ...]
# ['GERMAN', 'NET', 'CURRENCY', 'RESERVES', 'RISE', ...]
# ['CURRENCY', 'EXCHANGE', 'LOSS', 'PUSHES', 'MALAYSIA', ...]
# ['IWC', 'SAYS', 'EFFECT', 'OF', 'LOWER', 'SUPPORT', ...]
# ['U', '.', 'S', '.', 'TREASURY', "'", 'S', 'BAKER', ...]
# ['TREASURY', "'", 'S', 'BAKER', 'SAYS', 'HE', 'STANDS', ...]
# ['GERMAN', 'ANALYSTS', 'SEE', 'GOLD', 'RISING', 'IN', ...]
# ['CORADIAN', 'CORP', '&', 'lt', ';', 'CDIN', '>', ...]
# ['GULF', 'ESCORTS', 'STILL', 'UNDER', 'DISCUSSION', ...]
# ['FIRST', 'INTERSTATE', '&', 'lt', ';', 'I', '>', ...]
# ['FRENCH', 'UNEMPLOYMENT', 'RISES', 'TO', 'SEASONALLY', ...]
# ['MICKELBERRY', 'CORP', '&', 'lt', ';', 'MBC', '>', ...]
# ['MICKELBERRY', '&', 'lt', ';', 'MBC', '>', ...]
# ['F', '.', 'W', '.', 'WOOLWORTH', 'CO', '4TH', 'QTR', ...]
# ['FLUOROCARBON', 'CO', '&', 'lt', ';', 'FCBN', '>', ...]
# ['FRENCH', 'FEBRUARY', 'UNEMPLOYMENT', 'HITS', ...]
# ['PHILIPS', 'ELECTRICAL', 'SELLS', 'STAKE', 'IN', ...]
# ['AMERICAN', 'MEDICAL', 'INTERNATIONAL', 'INC', '2ND', ...]
# ['BAKER', 'SEES', '15', 'TO', '20', 'BILLION', 'DLR', ...]
# ['AMERICAN', 'MEDICAL', 'INTERNATIONAL', 'INC', '&', ...]
# ['HEINZ', 'INTERESTED', 'IN', 'BUYING', 'GUINNESS', ...]
# ['U', '.', 'K', '.', 'VISIBLE', 'TRADE', 'DEFICIT', ...]
# ['FRENCH', 'RESERVES', 'FALL', 'ON', 'DEBT', ...]
# ['FOOTE', 'MINERAL', 'CO', 'IN', 'LETTER', 'OF', ...]
# ['German', 'March', 'cost', 'of', 'living', '0', '.', ...]
# ['&', 'lt', ';', 'TRIZEC', 'CORP', 'LTD', '>', '1ST', ...]
# ['BOSTON', 'EDISON', 'CO', '&', 'lt', ';', 'BSE', '>', ...]
# ['GERMAN', 'COST', 'OF', 'LIVING', 'FALLS', 'IN', ...]
# ['EQUATORIAL', 'COMMUNICATIONS', '&', 'lt', ';', ...]
# ['FOOTE', 'MINERAL', '&', 'lt', ';', 'FTE', '>', 'TO', ...]
# ['U', '.', 'S', '.', 'FIRST', 'TIME', 'JOBLESS', ...]
# ['HONG', 'KONG', 'FEBRUARY', 'TRADE', 'SWINGS', 'INTO', ...]
# ['BEST', 'PRODUCTS', 'CO', 'INC', '4TH', 'QTR', 'SHR', ...]
# ['BEST', 'PRODUCTS', 'CO', '&', 'lt', ';', 'BES', '>', ...]
# ['TRANSAMERICA', '&', 'lt', ';', 'TA', '>', 'TO', ...]
# ['BANK', 'OF', 'SPAIN', 'PROVIDES', 'YEAR', 'RECORD', ...]
# ['ETHYL', 'CORP', '&', 'lt', ';', 'EY', '>', 'UNITS', ...]
# ['BRITISH', 'POLITICIANS', 'URGE', 'JAPAN', 'TRADE', ...]
# ['U', '.', 'K', '.', 'TRADE', 'FIGURES', 'BUOY', ...]
# ['S', '.', 'KOREA', 'MAY', 'BUY', 'U', '.', 'S', '.', ...]
# ['VIACOM', 'INTERNATIONAL', 'INC', 'GETS', 'ANOTHER', ...]
# ['BP', '&', 'lt', ';', 'BP', '>', 'TO', 'HOLD', 'NEW', ...]
# ['U', '.', 'S', '.', 'TREASURY', "'", 'S', 'MULFORD', ...]
# ['TREASURY', "'", 'S', 'MULFORD', 'SAYS', 'G', '-', ...]
# ['GERMAN', 'ANALYSTS', 'SEE', 'GOLD', 'FIRMING', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'RECEIVES', ...]
# ['BANK', 'OF', 'FRANCE', 'LEAVES', 'MONEY', 'MARKET', ...]
# ['MCO', '&', 'lt', ';', 'MCO', '>,', 'MAXXAM', '&', ...]
# ['F', '.', 'W', '.', 'WOOLWORTH', 'CO', '&', 'lt', ';', ...]
# ['PRICE', 'CO', '&', 'lt', ';', 'PCLB', '>', '2ND', ...]
# ['CAROLIAN', 'SYSTEMS', 'SEES', 'LOWER', 'FISCAL', ...]
# ['BANK', 'OF', 'FRANCE', 'BUYS', 'DOLLARS', ',', ...]
# ['U', '.', 'S', 'TREASURY', "'", 'S', 'MULFORD', ...]
# ['FRENCH', 'FREE', 'MARKET', 'CEREAL', 'EXPORT', ...]
# ['U', '.', 'S', '.', 'GOLD', 'EAGLE', 'SALES', ...]
# ['NEOAX', '&', 'lt', ';', 'NOAX', '>', 'TO', 'SELL', ...]
# ['PONCE', 'FEDERAL', 'BANK', 'FSB', '&', 'lt', ';', ...]
# ['FOOTHILL', 'GROUP', '&', 'lt', ';', 'FGI', '>', ...]
# ['BANK', 'OF', 'FRANCE', 'BUYS', 'DOLLARS', ',', ...]
# ['STANDARD', '&', 'lt', ';', 'SRD', '>', 'REFERRING', ...]
# ['ANCHOR', 'GLASS', '&', 'lt', ';', 'AGLS', '>', 'NOW', ...]
# ['MACNEAL', '-', 'SCHWENDLER', 'CORP', '&', 'lt', ';', ...]
# ['VIACOM', 'INTERNATIONAL', 'INC', '&', 'lt', ';', ...]
# ['BP', 'OIL', 'RAISES', 'OPERATING', 'PROFIT', '&', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'GETS', '25', ...]
# ['PHLCORP', '&', 'lt', ';', 'PHX', '>', 'HAS', ...]
# ['FOOTE', 'MINERAL', 'TO', 'MERGE', 'INTO', 'RIO', ...]
# ['ALUMINIUM', 'SCRAP', 'RECOVERY', 'AND', 'USAGE', ...]
# ['CROSS', 'AND', 'TRECKER', '&', 'lt', ';', 'CTCO', ...]
# ['SALANT', 'CORP', '&', 'lt', ';', 'SLT', '>', '1ST', ...]
# ['HEALTHMATE', 'INC', '&', 'lt', ';', 'HMTE', '>', ...]
# ['KEATING', 'REVISES', 'DOWN', 'AUSTRALIAN', 'GROWTH', ...]
# ['26', '-', 'FEB', '-', '1987', '26', '-', 'FEB', '-', ...]
# ['NATIONAL', 'BANC', 'OF', 'COMMERCE', 'CO', '&', 'lt', ...]
# ['HARSCO', 'CORP', '&', 'lt', ';', 'HSC', '>', 'SETS', ...]
# ['MADAGASCAR', 'COCOA', 'PRODUCTION', 'ESTIMATED', ...]
# ['COMPUTER', 'ASSOCIATES', '&', 'lt', ';', 'CA', '>', ...]
# ['SWISS', 'NET', 'CAPITAL', 'EXPORTS', 'RISE', 'IN', ...]
# ['ST', 'LAWRENCE', 'SEAWAY', 'OPENING', 'STILL', ...]
# ['DUTCH', 'GRAIN', 'LEVY', 'TEST', 'CASE', 'TO', ...]
# ['Z', '-', 'SEVEN', 'FUND', 'SEES', 'HIGHER', '1987', ...]
# ['U', '.', 'S', '.', 'ASKS', 'JAPAN', 'END', ...]
# ['SPANISH', 'REFINER', 'PLANS', 'GASOLINE', 'ADDITIVE', ...]
# ['WALL', 'STREET', 'STOCKS', '/', 'U', '.', 'S', '.', ...]
# ['ROY', 'F', '.', 'WESTON', 'INC', '&', 'lt', ';', ...]
# ['MOBIL', '&', 'lt', ';', 'MOB', '>', 'TO', 'UPGRADE', ...]
# ['BLOCKBUSTER', '&', 'lt', ';', 'BBEC', '>', 'TO', ...]
# ['BRAZIL', 'SOY', 'HARVEST', '13', 'PCT', 'COMPLETE', ...]
# ['CONTEL', '&', 'lt', ';', 'CTC', '>', 'TO', 'BUY', ...]
# ['MULFORD', 'SAYS', 'G', '-', '6', 'WANTS', ...]
# ['THERMO', 'PROCESS', '&', 'lt', ';', 'TPSI', '>', ...]
# ['SIEMENS', 'RAISES', 'STAKE', 'IN', 'TELECOM', 'PLUS', ...]
# ['FRUEHAUF', 'POSTS', '20', '.', '3', 'MLN', 'DLR', ...]
# ['MICHIGAN', 'GENERAL', '&', 'lt', ';', 'MGL', '>', ...]
# ['RABBIT', 'SOFTWARE', '&', 'lt', ';', 'RABT', '>', ...]
# ['COMSTOCK', 'GROUP', 'INC', '&', 'lt', ';', 'CSTK', ...]
# ['U', '.', 'S', '.', 'SENATE', 'HITS', 'EC', 'OILS', ...]
# ['HEALTHMATE', 'INC', 'SAYS', 'AUDITORS', 'INTEND', ...]
# ['HARSCO', 'CORP', '&', 'lt', ';', 'HSC', '>', 'SETS', ...]
# ['MILASTAR', 'CORP', '&', 'lt', ';', 'MILA', '>', ...]
# ['BANK', 'OF', 'BOSTON', 'EXPECTS', '1ST', 'QTR', ...]
# ['BANK', 'OF', 'BOSTON', '&', 'lt', ';', 'BKB', '>', ...]
# ['LIBYA', 'REPORTEDLY', 'BOUGHT', 'WHITE', 'SUGAR', ...]
# ['USAIR', 'GETS', 'APPROVAL', 'TO', 'BUY', '9', ',', ...]
# ['FED', 'EXPECTED', 'TO', 'ADD', 'RESERVES', 'The', ...]
# ['DOLLAR', '/', 'YEN', 'INTERVENTION', 'RESPONDS', ...]
# ['WALL', 'STREET', 'STOCKS', '/', 'U', '.', 'S', '.', ...]
# ['FIRSTCORP', '&', 'lt', ';', 'FCR', '>', 'SEES', ...]
# ['NORCEN', 'SEES', 'IMPROVEMENT', 'IN', '1987', ...]
# ['COCOA', 'COUNCIL', 'HEAD', 'TO', 'PRESENT', 'BUFFER', ...]
# ['SIEMENS', 'REBUTTS', 'U', '.', 'S', '.', 'CRITICISM', ...]
# ['MULFORD', 'DISAPPOINTED', 'IN', 'NEWLY', ...]
# ['FORD', '&', 'lt', ';', 'F', '>', 'NEARS', 'GM', '&', ...]
# ['MULFORD', 'SAYS', 'GERMANY', ',', 'JAPAN', 'SHOULD', ...]
# ['EC', 'GRANTS', 'EXPORT', 'LICENCES', '197', ',', ...]
# ['PIER', '1', 'IMPORTS', '&', 'lt', ';', 'PIR', '>', ...]
# ['LANCER', 'CORP', '&', 'lt', ';', 'LACR', '>', '4TH', ...]
# ['MACNEAL', '-', 'SCHWENDLER', 'CORP', '&', 'lt', ';', ...]
# ['NICHOLS', 'INSTITUTE', '&', 'lt', ';', 'LAB', '>', ...]
# ['FIRST', 'MEDICAL', 'DEVICES', 'CORP', '&', 'lt', ';', ...]
# ['HEALTHMATE', '&', 'lt', ';', 'HMTE', '>', 'EXPECTS', ...]
# ['HEALTHMATE', 'INC', '&', 'lt', ';', 'HMTE', '>', ...]
# ['USAIR', '&', 'lt', ';', 'U', '>', 'CLEARED', 'TO', ...]
# ['FED', 'SETS', 'TWO', 'BILLION', 'DLR', 'CUSTOMER', ...]
# ['HOUSE', 'OF', 'FABRICS', 'INC', '&', 'lt', ';', 'HF', ...]
# ['GERMAN', 'RETAILERS', 'EXPECT', 'GOOD', '1987', ...]
# ['GERMAN', 'WAGE', 'ROUND', 'SAID', 'TO', 'LIMIT', ...]
# ['FOREIGN', 'FIRMS', 'HOPE', 'TO', 'JOIN', 'JAPAN', ...]
# ['SIEMENS', 'RAISES', 'STAKE', 'IN', 'TELECOM', 'PLUS', ...]
# ['FIRST', 'INTERSTATE', 'SEEKS', 'ACQUISITION', 'Less', ...]
# ['&', 'lt', ';', 'NATIONAL', 'SEA', 'PRODUCTS', 'LTD', ...]
# ['HOUSE', 'OF', 'FABRICS', '&', 'lt', ';', 'HF', '>', ...]
# ['U', '.', 'S', '.', 'SENATE', 'HITS', 'EC', 'OILS', ...]
# ['KODAK', '&', 'lt', ';', 'EK', '>', 'BUYS', 'STAKE', ...]
# ['AVERY', '&', 'lt', ';', 'AVY', '>', '1ST', 'QTR', ...]
# ['FED', 'SETS', 'TWO', 'BILLION', 'DLR', 'CUSTOMER', ...]
# ['SENATE', 'SEEKS', 'U', '.', 'S', '.', 'PROBE', 'OF', ...]
# ['U', '.', 'K', '.', 'MONEY', 'MARKET', 'SHORTAGE', ...]
# ['KNIGHT', '-', 'RIDDER', 'INC', '&', 'lt', ';', 'KRN', ...]
# ['TECHNITROL', 'INC', '&', 'lt', ';', 'TNL', '>', ...]
# ['NATIONWIDE', 'CELLULAR', 'SERVICE', 'INC', '&', 'lt', ...]
# ['&', 'lt', ';', 'A', '.', 'H', '.', 'A', '.', ...]
